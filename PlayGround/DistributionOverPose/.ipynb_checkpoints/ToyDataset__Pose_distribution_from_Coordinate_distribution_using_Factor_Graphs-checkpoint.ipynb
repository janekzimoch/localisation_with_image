# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import lstsq

# %%
from tqdm import tqdm
import time

# %%
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture
from scipy.stats import norm
from sklearn.cluster import OPTICS

# %% [markdown]
# # Generate Dataset

# %% [markdown]
# the data generating process is:
#
# $y=ax$
#
# where **a** stands for pose, **y** for camera coordinates (camera bearings), and **x** for predicted world coordinates
#
# However, we don't know **x**, we only get a dsitribution over x from some upstream system of the pipeline. So **x** is modeled with a GMM:
#
# $p(x)=\sum^{K}_{k=1}\pi_k N(\mu_k, \sigma_k)$

# %% [markdown]
# For simplicity we assume that all **x** have K=3. And each datapoint will have $K*\{\pi,\mu,\sigma\}$ parameters, so 9 per datapoint. Therefore the dataset will be:
# * **y.shape = (dataset_size,)** - associated camera coordinate (which we know)
# * **x.shape = (dataset_size, 9)**
#
# The image which generated the data was ambigious and there are two modes which generated the data (i.e. if our upstream input was an image, then there would be two meanigful poses that we should be able to predict).
#
# Therefore there will some datapoints with two modes (1st stornger then the 2nd) and other where the 2nd mode is stronger than the 1st. Also there will be some outliers where all 3 modes are present with random choice of parameters

# %%
np.random.seed(seed=13)  # set seed so the dataset is the same whenever this NB is ran

dataset_size = 3000
num_modes = 3
noise = 0.005

x = np.random.uniform(-1,1, dataset_size)
x_predicted = np.empty((dataset_size, 3*num_modes))
x_mode = np.random.choice(num_modes, dataset_size)

a = np.random.uniform(-1,1,num_modes)
b = np.random.uniform(-0,0,num_modes)
pi_predicted = [[0.7,0.15,0.15], [0.15,0.7,0.15], [0.15,0.15,0.7]]

y = np.empty(x.shape)
# GET GOOD POINTS
for i in range(num_modes):
    y[x_mode == i] = x[x_mode == i] * a[i] + b[i] + np.random.normal(scale=noise, size=x[x_mode == i].shape)
    # set pi's
    x_predicted[x_mode == i, i*3] = 0.7
    x_predicted[x_mode != i, i*3] = 0.3 / (num_modes-1)
    
    # set means
    x_predicted[x_mode == i, i*3+1] = x[x_mode == i] + np.random.normal(scale=noise*0.2, size=x[x_mode == i].shape)
    x_predicted[x_mode != i, i*3+1] = ( y[x_mode != i] - b[i] ) / a[i] + np.random.normal(scale=noise*0.2, size=x[x_mode != i].shape)

    # set variances
    x_predicted[:, i*3+2] = 0.2

    
# GET OUTLIERS - outliers can be of different form - which form should I consider?
# I might want to consider what type of outliers i decide to have
num_outliers = int(0.1 * dataset_size)
y_tmp = np.random.uniform(y.min(), y.max(), size=num_outliers)
x_tmp = np.random.uniform(-1,1, num_outliers)
x_mode_tmp = np.ones(num_outliers) * num_modes

x = np.concatenate((x, x_tmp))
y = np.concatenate((y, y_tmp))
x_mode = np.concatenate((x_mode, x_mode_tmp))

x_predicted_tmp = np.empty((num_outliers,3*num_modes))
x_predicted_tmp[:, [0,3,6]] = 1.0/3
x_predicted_tmp[:, [1,4,7]] = np.random.uniform(-5,5,size=(num_outliers,3))
x_predicted_tmp[:, [2,5,8]] = 0.2
x_predicted = np.concatenate((x_predicted, x_predicted_tmp))

# %%
dataset = np.stack([x,y], axis=-1)
dataset.shape
# Out:
# (3300, 2)

# %%
fig, ax = plt.subplots(figsize = (10, 5))
for i in range(num_modes):
    ax.scatter(x[x_mode == i], y[x_mode == i], label=f'mode {i+1}')
    
ax.scatter(x[x_mode == num_modes], y[x_mode == num_modes], alpha=0.1, label=f'outliers')

# plot predicted probability distribution over 'x' for one of the points
ax2 = ax.twinx()
ind = 3
n_points = np.arange(x.min(), x.max(), (x.max()-x.min()) /1000)
probability = np.zeros(len(n_points))
for i in range(num_modes):
    probability += x_predicted[ind, i*3] * norm.pdf(n_points, 
                                                                loc=x_predicted[ind, i*3+1], 
                                                                scale=x_predicted[ind, i*3+2])
ax2.plot(n_points, probability)
print(f'y: {y[ind]}')
print(f'M1: pi={np.round(x_predicted[ind,0],2)}, mu={np.round(x_predicted[ind,1],3)}, \
      M2: pi={np.round(x_predicted[ind,3],2)}, mu={np.round(x_predicted[ind,4],3)}, \
      M3: pi={np.round(x_predicted[ind,6],2)}, mu={np.round(x_predicted[ind,7],3)}')
    


ax.legend(loc=2)
ax.set_ylabel('y')
ax2.set_ylabel('$p(x_i | img )$')
plt.xlabel('x')
ax.set_ylim((y.min()-0.1,y.max()+0.3))
plt.show()
# Out:
# y: 0.024075122386214336
# M1: pi=0.15, mu=0.001,       M2: pi=0.15, mu=0.0,       M3: pi=0.7, mu=0.934

# %% [markdown]
# # Get Inliers with RANSAC

# %%
def ransac(data, model, n, iterations, t, d, num_best_hypothesis=1, return_all=False, probability_dist=False):
    """
    data - a set of observed data points
    model - a model that can be fitted to data points
    n - the minimum number of data values required to fit the model
    iterations - the number of iterations to perform for ransac
    t - a threshold value for determining when a data point fits a model
    d - the number of close data values required to assert that a model fits well to data
    num_best_hypothesis - the number of best hypothesis that RANSAC should store and output.
    Return:
        bestfit - model parameters which best fit the data (or nil if no good model is found)
    """
    
    if probability_dist:
        iterations = 4*iterations  # An order of magnitude more itterations accounts forneed to sample from distribution.
        data, distribution = data
    
    bestfit = None
    besterr = np.inf
    best_inlier_idxs = None
    set_of_hypothesis = np.empty((iterations, 2))
    score_of_hypothesis = np.empty((iterations))
    

    # compute 'iterations' number of models
    for i in tqdm(range(iterations)):
#         t = time.time()

        maybe_idxs, test_idxs = random_partition(n,data.shape[0])
        
        maybeinliers = data[maybe_idxs]
        test_points = data[test_idxs]
        
        if probability_dist:
#             t1 = time.time()
            # we need to sample a value for each maybe and test index.
            maybeinliers = getRandomSamples(maybeinliers[:,:1], distribution[maybe_idxs])  # get a sample for each distribution defined by a row
            test_points = getRandomSamples(test_points[:,:1], distribution[test_idxs])
#             elapsed1 = time.time() - t1
            
        maybemodel = model.fit(maybeinliers)
        
        test_err = model.get_error(test_points, maybemodel)  # this gets error per point
        also_idxs = test_idxs[test_err < t]  # here we select indexes of other point which lie within the threshold. 
        
        inlier_score = float(len(also_idxs) + n) / data.shape[0]
        set_of_hypothesis[i] = np.reshape(maybemodel, 2)
        score_of_hypothesis[i] = inlier_score
        
        # do stuff
#         elapsed = time.time() - t
#         print(f'total time: {elapsed}, sampling took: {(elapsed-elapsed1)*100/elapsed} %')

        
    # sort all model hypothesis by their inlier score
    sorted_indexes = np.argsort(score_of_hypothesis)[::-1]
    sorted_hypothesis = set_of_hypothesis[sorted_indexes]
    sorted_hyp_scores = score_of_hypothesis[sorted_indexes]
    # take 5% best poses from K itterations
    frac_of_K = 0.05
    num_best_hyp = int(frac_of_K * iterations)
    if num_best_hyp < 2:
        num_best_hyp = 2
    best_sorted_hypothesis = sorted_hypothesis[:num_best_hyp]
    
    plt.hist(sorted_hypothesis[:,0], density=True, bins=int(30/frac_of_K), alpha=0.2)
#     plt.hist(sorted_hypothesis[:,0], density=True, weights=sorted_hyp_scores, bins=int(30/frac_of_K), alpha=0.1)
    plt.hist(best_sorted_hypothesis[:,0], density=True, bins=30)
    plt.show()
    
    
    # get BEst hypothesis - note: the number of est hypothesisdepends on the solution of the clustering method
    # each cluster should have number of elements a minimum of 0.5% 
    min_smp = int(frac_of_K * 0.05 * iterations)
    if min_smp < 1:
        min_smp = 1
    best_pose_clustering = OPTICS(min_samples=min_smp).fit(np.expand_dims(best_sorted_hypothesis[:,0], axis=-1))
    clustering_assignments = best_pose_clustering.labels_

    num_best_hypothesis = len(np.unique(clustering_assignments))
    best_hypothesis = [None] * num_best_hypothesis
    print(num_best_hypothesis)
    for i, clust in enumerate(np.unique(clustering_assignments)):
        hypothesis = best_sorted_hypothesis[clustering_assignments == clust]
        best_hypothesis[i] = np.mean(hypothesis, axis=0)

    
    # for 'num_best_hypothesis' best models, get imporved model - based on all inlier points - and get indeces of inliers
    best_models = [None] * num_best_hypothesis
    models_inlier_indexes = [None] * num_best_hypothesis
    for i in range(num_best_hypothesis):
        # get inlier data points
        data_samples = getRandomSamples(data[:,:1], distribution, samples_per_point=5)
        test_err = model.get_error(data_samples, np.reshape(best_hypothesis[i], (2,1)))
        inlier_indexes = test_err < t
        models_inlier_indexes[i] = inlier_indexes  # i will have to figure out how to go from sample indexes back to point indexes
        
        # get model
        best_models[i] = model.fit(data_samples[inlier_indexes])
        
    return num_best_hypothesis, best_models, models_inlier_indexes, best_sorted_hypothesis


def random_partition(n,n_data):
    """return n random rows of data (and also the other len(data)-n rows)"""
    all_idxs = np.arange( n_data )
    np.random.shuffle(all_idxs)
    idxs1 = all_idxs[:n]
    idxs2 = all_idxs[n:]
    return idxs1, idxs2
                                                 

def getRandomSamples(y, distributions, samples_per_point=1):
    """ distribution is defined as follows: has 9 columns, columns [0,3,6] correspond to mixing components
    columns [1,4,7] correspond to means, and columns [2,5,8] corespond to variances """
    y = np.concatenate([y]*samples_per_point, axis=0)
    samples = np.empty((len(distributions) * samples_per_point, 1))
    for i in range(len(distributions)):
        mix_ID = np.random.choice([0,1,2], size=samples_per_point, replace=True, p=distributions[i, [0,3,6]])
        for j, m_id in enumerate(mix_ID):
            samples[i*samples_per_point + j] = np.random.normal(loc=distributions[i, m_id*3+1], scale=distributions[i, m_id*3+2], size=1)
   
    xy = np.concatenate([y,samples], axis=1)
    return xy

# %%
class LinearLeastSquaresModel:
    """linear system solved using linear least squares

    This class serves as an example that fulfills the model interface
    needed by the ransac() function.
    
    """
    def __init__(self,input_columns,output_columns,debug=False):
        self.input_columns = input_columns
        self.output_columns = output_columns
        self.debug = debug
    def fit(self, data):
        A = np.vstack([data[:,i] for i in self.input_columns]).T
        A = np.concatenate([A,np.ones(A.shape)], axis=-1) # add 1s for intercept

        B = np.vstack([data[:,i] for i in self.output_columns]).T
        x,resids,rank,s = lstsq(A,B)  # scipy.linalg.lstsq
        return x
    
    def get_error( self, data, model):
        A = np.vstack([data[:,i] for i in self.input_columns]).T
        A = np.concatenate([A,np.ones(A.shape)], axis=-1) # add 1s for intercept
        
        B = np.vstack([data[:,i] for i in self.output_columns]).T
        B_fit = np.dot(A,model)
        err_per_point = np.sum((B-B_fit)**2,axis=1) # sum squared error per row
        return err_per_point

# %%
# ransac:
# INPUT: entire dataset
# OUTPUT: set of M points which are considered inliers

data = [dataset, x_predicted]
model = LinearLeastSquaresModel([0],[1])
n = 5  # this needs to be low if we want to capture all true poses
k = 1
t = 0.001
d = 100
probability_dist = True

N = 2
N, model_parameters, inlier_indexes, five_percentile_best_poses = ransac(data,model,n,k,t,d,num_best_hypothesis=N, return_all=True, probability_dist=probability_dist)
# Out:
# 100%|██████████| 44/44 [00:10<00:00,  4.21it/s]
# 1

# %% [markdown]
# # Get distribution over pose
# ## Factor Graph probability propagation from inliers

# %%
# i need some way to modify ransac, such that it can operate on probability distribution rather than samples.
# so i would need to embed FACTOR GRAPH within the RANSAC
# for each itteration just compute the pose given 3D coordinates.
# and then when computing the inlier score. we would be evaluating probability of eachpoint to be generated by the computed pose.
# and the threshold would be the minimum probability to accept the datapoint as an inlier.

# %% [markdown]
# we have a product of gaussian mixtures - computation of which is non trivial - it will have M^2 mixtures
# possible inference algorithm - Nonparametric Belief Propagation (NBP)
# NBP ca approximate product of gaussian mixtures with an efficient Gibbs sampling procedure,
# allowing a natural tradeoff between statistical accuracy and computational efficiency.
#
# My idea:
# let Z = X * Y, where both X and Y are GMMs with M mixtures each
# maybe we can conduct this product by itterating through all M gaussian mixtures of Y,
# and multiplying X by each gaussian, weighted by the mixing component of Ys mixture.
# Then we just sum over all of these M products.
#
# but a product of two gaussian PDFs is a gaussian with a new mean and variance. Therefore we will have M*M mixtures afterwards.
# and if the product consists of D gaussian mixtures where each has M modes, we will have M^D mixtures afterwards.
# this seems computationally doable but prohibitive.
#
# QUESTIONS TO ANSWER:
# the distribution over poses will be GMM with M^D mixtures.
# How can I simplify it? and what if i want to use different distribution representation
# SOLUTION:
# WITH GIBBS SAMPLING AS DESCRIBED HERE: http://ssg.mit.edu/nbp/papers/LIDS-TR2551.pdf

# %%
#to avoid numerical underflow we cna move to log space and additions.

# %%
# 1. FACTOR GRAPH - given M 'x' distributions, compute distribution over pose a
indexes = [1,2,3,4]
x_predicted[indexes]

def get_distribution_over_pose(coord_dists, num_modes):
    """
    This function computes a marginal distribution over pose, using a factor graph.
    coord_dists - shape=(M, modes*3) distribution for M datapoints  
    modes - number of mixtures in dist. over coordinates - dist. over poses will have the same number of mixtures
    """    
    # get initial pose distribution parameters (i.e. as if we were computing pose based on only a single coordinate distribution)
    p_pi = np.array([coord_dists[0,3*i] for i in range(num_modes)])
    p_mean = np.array([coord_dists[0,3*i+1] for i in range(num_modes)])
    p_sigma = np.array([coord_dists[0,3*i+2] for i in range(num_modes)])
    
    p_dist_modes = num_modes
    for dist in tqdm(coord_dists[1:]):
        
        p_pi_new = np.empty(p_dist_modes * num_modes)
        p_mean_new = np.empty(p_dist_modes * num_modes)
        p_sigma_new = np.empty(p_dist_modes * num_modes)
        
        # get distribution parameters
        pi = np.array([dist[3*i] for i in range(num_modes)])
        mean = np.array([dist[3*i+1] for i in range(num_modes)])
        sigma = np.array([dist[3*i+2] for i in range(num_modes)])
        
        # for each mode of 'pos_dist' multiply it by a mode of 'dist'
        for i in range(p_dist_modes):
            for m in range(num_modes): 
                # multypling two gaussians
                p_pi_new[i*num_modes + m] = pi[m] * p_pi[i]
                p_mean_new[i*num_modes + m] = (p_sigma[i]*mean[m] + sigma[m]*p_mean[i])/(sigma[m]+p_sigma[i])
                p_sigma_new[i*num_modes + m] = 1/(1/sigma[m] + 1/p_sigma[i])
    
        p_dist_modes *= num_modes
        p_pi = p_pi_new.copy()
        p_mean = p_mean_new.copy()
        p_sigma = p_sigma_new.copy()
    
    return p_pi, p_mean, p_sigma


# the above works but uses a triple for loop...
# if this function is critical I will replace the double loop with more efficient matrix multiplication

# %%
def visualise_GMM(pi, mean, sigma):
    num_modes = len(pi)
    
    n = 1000
    min_ = mean.min() - sigma.max()
    max_ = mean.max() + sigma.max()
    n_points = np.arange(min_, max_, (max_-min_)/1000)
    
    cumul_probability = np.zeros(len(n_points))
    for p, m, s in zip(pi, mean, sigma):
        probability = p * norm.pdf(n_points, loc=m, scale=np.sqrt(s))
        cumul_probability += probability
        plt.plot(n_points, probability)
        
    plt.plot(n_points, cumul_probability)
    plt.show()
    
def split_GMM_params(dist, num_modes):
    pi = np.array([dist[3*i] for i in range(num_modes)])
    mean = np.array([dist[3*i+1] for i in range(num_modes)])
    sigma = np.array([dist[3*i+2] for i in range(num_modes)])
    return pi, mean, sigma

# %%
# 2. Do visualisations of the FACTOR GRAPH computation
pi_pose_dist, mean_pose_dist, sigma_pose_dist = get_distribution_over_pose(x_predicted[:4], num_modes)

# plot  'coord_dists[:4]'
pi, mean, sigma = split_GMM_params(x_predicted[0], num_modes)
visualise_GMM(pi, mean, sigma)

pi, mean, sigma = split_GMM_params(x_predicted[1], num_modes)
visualise_GMM(pi, mean, sigma)

pi, mean, sigma = split_GMM_params(x_predicted[2], num_modes)
visualise_GMM(pi, mean, sigma)

pi, mean, sigma = split_GMM_params(x_predicted[3], num_modes)
visualise_GMM(pi, mean, sigma)

# plot 'pose_distiribution'
visualise_GMM(pi_pose_dist, mean_pose_dist, sigma_pose_dist)

# 3. Design RANSAC function - what computations have to happen? write PSUDO code.
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 2407.29it/s]

# %%
# TODO: think how this can be used to compute dist over pose.
# we forgot to divide by y. which will modify mean and variance.

# %% [markdown]
# In my toy example (which doesn't involve a PnP problem, but a linear mapping from coordinates to pose) evaluation of marginal distribution over pose using a factor graph is complicated and expensive. A product of D gaussian mixtures where each mixture has M components, is itself a gaussian mixture model with M^D mixture components. (where D depends on the number of inliers points we want to consider when computing the pose).
#
# When used within RANSAC it doesn't seem to be a problem as for each RANSAC iteration D is small. However (1) once we identify all the inliers and want to use all of them to get a final distribution over pose then having GMM with M^D mixtures sounds redundant. (2) If we decide to model distribution over pose with a different distribution to a GMM, then I'm also not sure how we could proceed.
#
# Question: I looked at the Nonparametric Belief Propagation (NBP) where they use gibbs sampling
