# %%
from utilis.utilis import *
from get_datasets import *

# %% [markdown]
# # Custom dataset

# %%
data = get_dataset__simplified_localisation_problem()
x, y, cluster_assignment = data['train']
plot_dataset(x, y, cluster_assignment, title="Custom dataset")

# %% [markdown]
# # Mixture of innverted sinusoids dataset

# %%
data = get_dataset__inverted_sinusoid()
x, y, cluster_assignment = data['train']
plot_dataset(x, y, cluster_assignment, title="sinusoidal dataset")

# %% [markdown]
# # Mixture of linear functions dataset

# %%
data = get_dataset__many_linear_functions()
x, y, cluster_assignment = data['train']
plot_dataset(x, y, cluster_assignment, title="Linear dataset")
