# %%
from run_experiment import *

# %%
run_experiment('configs.json')
# Out:
# Setting up Experiment folder ...
# 2021-04-14/test_2021-04-14_16:59:44
# Partitionin gdataset IDs ...
# Setting up data Generators ...
# Getting callbacks ...
# Setting up model ...
# Training ...
# Epoch 1/2
#  1/88 [..............................] - ETA: 0s - loss: 4.1893WARNING:tensorflow:From /home/mlmi-2020/jz522/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# ...
# 88/88 [==============================] - ETA: 0s - loss: 2.6107#############     TRAIN     #############
# /home/mlmi-2020/jz522/localisation_from_image_project/code/utilis/callbacks.py:98: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar1.ax.set_yticklabels(['0','1','2','3','4','5','6+'])
# #############   VALIDATION   #############
# ...
