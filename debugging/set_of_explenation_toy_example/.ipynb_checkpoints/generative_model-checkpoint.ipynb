# %%
from utilis.utilis import *
from utilis.mdn_utilis import *
from utilis.gen_model_utilis import *
from get_datasets import *

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import numpy as np
from scipy import spatial
from scipy.stats import norm, uniform
from tqdm import tqdm

# %% [markdown]
# # Mixture of linear functions dataset

# %% [markdown]
# I skiped this one for now.
#
# Mixture of inverted sinusoids didn't work that well so may want to verify method on this dataset

# %%
num_components = 10
data = get_dataset__many_linear_functions(N = 1000, num_components=num_components)
x, y, cluster_assignment, epsilon, y_shift = data['train']
plot_dataset(x, y, cluster_assignment, title="Mixture of Linear Fucntions dataset")

# %%
model = simple_model(input_shape=1+num_components)

# %%
# one-hot-encode cluster_assignment dataset
clusters_one_hot = np.zeros((cluster_assignment.size, cluster_assignment.max()+1))
clusters_one_hot[np.arange(cluster_assignment.size), cluster_assignment] = 1

# %%
epochs = 50
model_input = np.concatenate([y.reshape(-1, 1), clusters_one_hot], axis=-1)
print(model_input.shape)
model.fit(model_input, x, epochs=epochs)
# Out:
# (900, 11)
# Epoch 1/50
# 29/29 [==============================] - 0s 2ms/step - loss: 13.0855
# Epoch 2/50
# 29/29 [==============================] - 0s 2ms/step - loss: 4.1198
# Epoch 3/50
# 29/29 [==============================] - 0s 3ms/step - loss: 2.9477
# Epoch 4/50
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8319
# Epoch 5/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.8960
# Epoch 6/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5408
# Epoch 7/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4116
# Epoch 8/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3401
# Epoch 9/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2694
# Epoch 10/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2500
# Epoch 11/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1882
# Epoch 12/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1744
# Epoch 13/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1491
# Epoch 14/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1358
# Epoch 15/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1309
# Epoch 16/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1233
# Epoch 17/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1180
# Epoch 18/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0994
# Epoch 19/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1033
# Epoch 20/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1055
# Epoch 21/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0783
# Epoch 22/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0681
# Epoch 23/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0596
# Epoch 24/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0637
# Epoch 25/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0483
# Epoch 26/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0702
# Epoch 27/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0400
# Epoch 28/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0447
# Epoch 29/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0399
# Epoch 30/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0294
# Epoch 31/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0270
# Epoch 32/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0242
# Epoch 33/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0209
# Epoch 34/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 35/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 36/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0164
# Epoch 37/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 38/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0149
# Epoch 39/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 40/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0220
# Epoch 41/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 42/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 43/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 44/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 45/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 46/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0123
# Epoch 47/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 48/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 49/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 50/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0123

# %%
x_test, y_test, cluster_assignment_test, epsilon, y_shifts = data['test']

# one-hot-encode cluster_assignment dataset
clusters_one_hot_test = np.zeros((cluster_assignment_test.size, cluster_assignment_test.max()+1))
clusters_one_hot_test[np.arange(cluster_assignment_test.size), cluster_assignment_test] = 1
model_input = np.concatenate([y_test.reshape(-1, 1), clusters_one_hot_test], axis=-1)

x_pred = model.predict(model_input)
plt.scatter(x_pred, y_test)
plt.title('ealuate quality of p(x|y,epsilon)')
plt.show()

# %%
N_y = 4000
N_x = 4000
x_range = [-10,8]
y_range = [-12,6]

# %%
x_sample = 0
p_y_given_x = get_distribution_p_y_x(x_sample, model, num_components, y_shifts, y_range, N_y)

# %%
plot_p_y_x(p_y_given_x, y_range, N_y, y, x, x_sample)

# %%
x_queries = np.arange(x_range[0], x_range[1], (x_range[1] - x_range[0]) / N_x)
heat_map = get_heat_map_p_y_x(x_queries, model, num_components, y_shifts, y_range, N_y)

# %%
plot_heat_map(heat_map, x_range, y_range, N_x, N_y, tick_freq=1000)
plt.show()

# %% [markdown]
# # Mixture of inverted sinusoids

# %% [markdown]
# ## 1. single sinusoid

# %% [markdown]
# \begin{align}
# p(x,y,\epsilon) = p(x|y,\epsilon)p(y)p(\epsilon)
# \end{align}
#
# * $p(y)$ = Uniform(-1,1)
# * $p(\epsilon)$ = N(0,0.1)
# * $p(x|y,\epsilon)$ = approximate with neural network

# %% [markdown]
# ### A. Get dataset

# %%
data = get_dataset__inverted_sinusoid(N=1000, num_sinusoids=1)
x, y, cluster_assignment, epsilon = data['train']
plot_dataset(x, y, cluster_assignment, title="sinusoidal dataset")

# %% [markdown]
# ### B. Train $p(x|t,\epsilon)$

# %%
model = simple_model(input_shape=1)

# %%
epochs = 100
model.fit(y, x, epochs=epochs, verbose=0)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 0s 2ms/step - loss: 12.8719
# Epoch 2/100
# 29/29 [==============================] - 0s 2ms/step - loss: 5.5715
# Epoch 3/100
# 29/29 [==============================] - 0s 2ms/step - loss: 5.2656
# Epoch 4/100
# 29/29 [==============================] - 0s 2ms/step - loss: 5.1999
# Epoch 5/100
# 29/29 [==============================] - 0s 2ms/step - loss: 5.2298
# Epoch 6/100
# 29/29 [==============================] - 0s 2ms/step - loss: 5.0167
# Epoch 7/100
# 29/29 [==============================] - 0s 2ms/step - loss: 4.9575
# Epoch 8/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.8517
# Epoch 9/100
# 29/29 [==============================] - 0s 2ms/step - loss: 4.7158
# Epoch 10/100
# 29/29 [==============================] - 0s 2ms/step - loss: 4.5644
# Epoch 11/100
# 29/29 [==============================] - 0s 2ms/step - loss: 4.3657
# Epoch 12/100
# 29/29 [==============================] - 0s 2ms/step - loss: 4.1164
# Epoch 13/100
# 29/29 [==============================] - 0s 2ms/step - loss: 3.7723
# Epoch 14/100
# 29/29 [==============================] - 0s 2ms/step - loss: 3.4378
# Epoch 15/100
# 29/29 [==============================] - 0s 1ms/step - loss: 2.9811
# Epoch 16/100
# 29/29 [==============================] - 0s 2ms/step - loss: 2.7030
# Epoch 17/100
# 29/29 [==============================] - 0s 1ms/step - loss: 2.3473
# Epoch 18/100
# 29/29 [==============================] - 0s 2ms/step - loss: 2.1792
# Epoch 19/100
# 29/29 [==============================] - 0s 2ms/step - loss: 2.0722
# Epoch 20/100
# 29/29 [==============================] - 0s 2ms/step - loss: 2.0105
# Epoch 21/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.9143
# Epoch 22/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.8999
# Epoch 23/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8463
# Epoch 24/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7592
# Epoch 25/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6879
# Epoch 26/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6183
# Epoch 27/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5392
# Epoch 28/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5573
# Epoch 29/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3695
# Epoch 30/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3014
# Epoch 31/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2103
# Epoch 32/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1763
# Epoch 33/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0912
# Epoch 34/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0077
# Epoch 35/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.9365
# Epoch 36/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.8908
# Epoch 37/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.8266
# Epoch 38/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.7644
# Epoch 39/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7324
# Epoch 40/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6872
# Epoch 41/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6949
# Epoch 42/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6288
# Epoch 43/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6096
# Epoch 44/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5697
# Epoch 45/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5428
# Epoch 46/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5155
# Epoch 47/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4941
# Epoch 48/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4897
# Epoch 49/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4665
# Epoch 50/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4479
# Epoch 51/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4252
# Epoch 52/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4272
# Epoch 53/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4229
# Epoch 54/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3944
# Epoch 55/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3732
# Epoch 56/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3957
# Epoch 57/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4131
# Epoch 58/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3503
# Epoch 59/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3385
# Epoch 60/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3362
# Epoch 61/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3682
# Epoch 62/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3407
# Epoch 63/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3367
# Epoch 64/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3222
# Epoch 65/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3052
# Epoch 66/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3213
# Epoch 67/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3167
# Epoch 68/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3483
# Epoch 69/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2926
# Epoch 70/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2894
# Epoch 71/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3022
# Epoch 72/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2907
# Epoch 73/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3005
# Epoch 74/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3010
# Epoch 75/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2834
# Epoch 76/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3438
# Epoch 77/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3102
# Epoch 78/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3261
# Epoch 79/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2703
# Epoch 80/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2826
# Epoch 81/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2780
# Epoch 82/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2730
# Epoch 83/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3218
# Epoch 84/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2722
# Epoch 85/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2951
# Epoch 86/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3515
# Epoch 87/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2999
# Epoch 88/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2874
# Epoch 89/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2756
# Epoch 90/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2909
# Epoch 91/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2660
# Epoch 92/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2715
# Epoch 93/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2798
# Epoch 94/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2711
# Epoch 95/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2685
# Epoch 96/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2725
# Epoch 97/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2870
# Epoch 98/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2972
# Epoch 99/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2788
# Epoch 100/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2960

# %%
x_test, y_test, cluster_assignment_test, epsilon_test = data['test']

# model_input = np.stack([y_test, epsilon_test]).T
x_pred = model.predict(y_test)
plt.scatter(x_pred, y_test)
plt.title('ealuate quality of p(x|y,epsilon)')
plt.show()

# %% [markdown]
# ### C. get $p(y|x) = \frac{\frac{1}{D}\sum^{D}_{i=1}p(x|y,\epsilon_i)p(y)p(\epsilon_i)}{\frac{1}{D}\sum^{D}_{i=1}\sum^{M}_{j=1}p(x|y_j,\epsilon_i)p(y_j)p(\epsilon_i)}$   where: $y_j \sim Uniform(-1,1)$ and $\epsilon_i \sim N(0,0.1)$

# %% [markdown]
# let's assume that p(x|y,epsilon) is a gaussian N(x;f(y), sigma) and that we are predicting just means assuming constant noise. So in effect we don't need to sum over epsilon because noise is implicit.

# %%
N_y = 500
N_x = 500
x_range = [-2,8]
y_range = [-6,0]

# %%
x_sample = 4
p_y_given_x = get_distribution_p_y_x(x_sample, model, y_range, N_y)

# %%
plot_p_y_x(p_y_given_x, y_range, N_y, y_test, x_test, x_sample)

# %% [markdown]
# ### D. get a heatmap

# %%
x_queries = np.arange(x_range[0], x_range[1], (x_range[1] - x_range[0]) / N_x)
heat_map = get_heat_map_p_y_x(x_queries, model, y_range, N_y)

plot_heat_map(heat_map, x_range, y_range, N_x, N_y)
plt.show()

# %% [markdown]
# ## 2. mixture of sinusoids

# %% [markdown]
# \begin{align}
# p(x,y, c, \epsilon) = p(x|y,c,\epsilon)p(y|c)p(c)p(\epsilon)
# \end{align}
#
# * $p(y|c_i) = N(g(c_i), 1)$
# * $p(c)$ = Categorical_Uniform(5 categories)
# * $p(\epsilon)$ = N(0,0.1)
# * $p(x|y,c,\epsilon)$ = approximate with neural network

# %%
num_sinusoids = 5
data = get_dataset__inverted_sinusoid(N=1000, num_sinusoids=num_sinusoids)
x, y, cluster_assignment, y_shifts = data['train']
plot_dataset(x, y, cluster_assignment, title="sinusoidal dataset")

# %% [markdown]
# ### A. Train $p(x|y,c,\epsilon)$

# %%
model = simple_model(input_shape=(1+num_sinusoids))

# %%
# one-hot-encode cluster_assignment dataset
clusters_one_hot = np.zeros((cluster_assignment.size, cluster_assignment.max()+1))
clusters_one_hot[np.arange(cluster_assignment.size), cluster_assignment] = 1

# %%
epochs = 500
model_input = np.concatenate([y.reshape(-1, 1), clusters_one_hot], axis=-1)
print(model_input.shape)
model.fit(model_input, x, epochs=epochs)
# Out:
# (900, 6)
# Epoch 1/500
# 29/29 [==============================] - 0s 1ms/step - loss: 91.3394
# Epoch 2/500
# 29/29 [==============================] - 0s 1ms/step - loss: 62.3627
# Epoch 3/500
# 29/29 [==============================] - 0s 2ms/step - loss: 36.5687
# Epoch 4/500
# 29/29 [==============================] - 0s 1ms/step - loss: 8.5897
# Epoch 5/500
# 29/29 [==============================] - 0s 2ms/step - loss: 2.9553
# Epoch 6/500
# 29/29 [==============================] - 0s 2ms/step - loss: 2.4330
# Epoch 7/500
# 29/29 [==============================] - 0s 2ms/step - loss: 2.1539
# Epoch 8/500
# 29/29 [==============================] - 0s 2ms/step - loss: 2.0793
# Epoch 9/500
# 29/29 [==============================] - 0s 2ms/step - loss: 2.0104
# Epoch 10/500
# 29/29 [==============================] - 0s 2ms/step - loss: 1.7847
# Epoch 11/500
# 29/29 [==============================] - 0s 2ms/step - loss: 1.4152
# Epoch 12/500
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2096
# Epoch 13/500
# 29/29 [==============================] - 0s 2ms/step - loss: 1.1487
# Epoch 14/500
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1055
# Epoch 15/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.9433
# Epoch 16/500
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0624
# Epoch 17/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.9490
# Epoch 18/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.8795
# Epoch 19/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7875
# Epoch 20/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7562
# Epoch 21/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.8156
# Epoch 22/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.7313
# Epoch 23/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.7093
# Epoch 24/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6217
# Epoch 25/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5938
# Epoch 26/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6099
# Epoch 27/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5865
# Epoch 28/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6766
# Epoch 29/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5227
# Epoch 30/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5543
# Epoch 31/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5015
# Epoch 32/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4836
# Epoch 33/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4343
# Epoch 34/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4671
# Epoch 35/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4265
# Epoch 36/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3805
# Epoch 37/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4247
# Epoch 38/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3830
# Epoch 39/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4240
# Epoch 40/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4352
# Epoch 41/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5141
# Epoch 42/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3436
# Epoch 43/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3707
# Epoch 44/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6099
# Epoch 45/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3453
# Epoch 46/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2774
# Epoch 47/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2740
# Epoch 48/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3452
# Epoch 49/500
# 29/29 [==============================] - 0s 4ms/step - loss: 0.3292
# Epoch 50/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2340
# Epoch 51/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2337
# Epoch 52/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2252
# Epoch 53/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2147
# Epoch 54/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2047
# Epoch 55/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1781
# Epoch 56/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1686
# Epoch 57/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1846
# Epoch 58/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1683
# Epoch 59/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1682
# Epoch 60/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2030
# Epoch 61/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1502
# Epoch 62/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1615
# Epoch 63/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2428
# Epoch 64/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1729
# Epoch 65/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1519
# Epoch 66/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1260
# Epoch 67/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1257
# Epoch 68/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1485
# Epoch 69/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1583
# Epoch 70/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1241
# Epoch 71/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1143
# Epoch 72/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1270
# Epoch 73/500
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1176
# Epoch 74/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1113
# Epoch 75/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1089
# Epoch 76/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1329
# Epoch 77/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2167
# Epoch 78/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1269
# Epoch 79/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1153
# Epoch 80/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1316
# Epoch 81/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1191
# Epoch 82/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1339
# Epoch 83/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1150
# Epoch 84/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0952
# Epoch 85/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1225
# Epoch 86/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1003
# Epoch 87/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0927
# Epoch 88/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1032
# Epoch 89/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1030
# Epoch 90/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0900
# Epoch 91/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1030
# Epoch 92/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0863
# Epoch 93/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1003
# Epoch 94/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1359
# Epoch 95/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1273
# Epoch 96/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1069
# Epoch 97/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1037
# Epoch 98/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1209
# Epoch 99/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1019
# Epoch 100/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1206
# Epoch 101/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1115
# Epoch 102/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0973
# Epoch 103/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1172
# Epoch 104/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1047
# Epoch 105/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0886
# Epoch 106/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1025
# Epoch 107/500
# 29/29 [==============================] - ETA: 0s - loss: 0.124 - 0s 2ms/step - loss: 0.1210
# Epoch 108/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 109/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0837
# Epoch 110/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0864
# Epoch 111/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0965
# Epoch 112/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1207
# Epoch 113/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0817
# Epoch 114/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0926
# Epoch 115/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1238
# Epoch 116/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0896
# Epoch 117/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0834
# Epoch 118/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0918
# Epoch 119/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0955
# Epoch 120/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0990
# Epoch 121/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1175
# Epoch 122/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0759
# Epoch 123/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0815
# Epoch 124/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0739
# Epoch 125/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1195
# Epoch 126/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0912
# Epoch 127/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0988
# Epoch 128/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 129/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1666
# Epoch 130/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1053
# Epoch 131/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0816
# Epoch 132/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3893
# Epoch 133/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1182
# Epoch 134/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1538
# Epoch 135/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1091
# Epoch 136/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 137/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0968
# Epoch 138/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0728
# Epoch 139/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0637
# Epoch 140/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0760
# Epoch 141/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0964
# Epoch 142/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0984
# Epoch 143/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0843
# Epoch 144/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0694
# Epoch 145/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0785
# Epoch 146/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0763
# Epoch 147/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0633
# Epoch 148/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0625
# Epoch 149/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0902
# Epoch 150/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 151/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0675
# Epoch 152/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0854
# Epoch 153/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0715
# Epoch 154/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0640
# Epoch 155/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0735
# Epoch 156/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1599
# Epoch 157/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1712
# Epoch 158/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1691
# Epoch 159/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0974
# Epoch 160/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 161/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0699
# Epoch 162/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0679
# Epoch 163/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0644
# Epoch 164/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 165/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 166/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1051
# Epoch 167/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0869
# Epoch 168/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0774
# Epoch 169/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0637
# Epoch 170/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0825
# Epoch 171/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0671
# Epoch 172/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0745
# Epoch 173/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0674
# Epoch 174/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 175/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0567
# Epoch 176/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0620
# Epoch 177/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0686
# Epoch 178/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1674
# Epoch 179/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0986
# Epoch 180/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0693
# Epoch 181/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0681
# Epoch 182/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0497
# Epoch 183/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0509
# Epoch 184/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0601
# Epoch 185/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0549
# Epoch 186/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0526
# Epoch 187/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0463
# Epoch 188/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0546
# Epoch 189/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 190/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0557
# Epoch 191/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0555
# Epoch 192/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0935
# Epoch 193/500
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0556
# Epoch 194/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0517
# Epoch 195/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0710
# Epoch 196/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0552
# Epoch 197/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0548
# Epoch 198/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0511
# Epoch 199/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0487
# Epoch 200/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0703
# Epoch 201/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0625
# Epoch 202/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0624
# Epoch 203/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0565
# Epoch 204/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0728
# Epoch 205/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0791
# Epoch 206/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0647
# Epoch 207/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0500
# Epoch 208/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0642
# Epoch 209/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0468
# Epoch 210/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0412
# Epoch 211/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0436
# Epoch 212/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0507
# Epoch 213/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0467
# Epoch 214/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0421
# Epoch 215/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0469
# Epoch 216/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0462
# Epoch 217/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0706
# Epoch 218/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 219/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0577
# Epoch 220/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0686
# Epoch 221/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0685
# Epoch 222/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0551
# Epoch 223/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0565
# Epoch 224/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0465
# Epoch 225/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0655
# Epoch 226/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0904
# Epoch 227/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1070
# Epoch 228/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1173
# Epoch 229/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0487
# Epoch 230/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0503
# Epoch 231/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0611
# Epoch 232/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0786
# Epoch 233/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 234/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0819
# Epoch 235/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0505
# Epoch 236/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0838
# Epoch 237/500
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0484
# Epoch 238/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0433
# Epoch 239/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0435
# Epoch 240/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0360
# Epoch 241/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0577
# Epoch 242/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0705
# Epoch 243/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0400
# Epoch 244/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0403
# Epoch 245/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0354
# Epoch 246/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 247/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0434
# Epoch 248/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0384
# Epoch 249/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0404
# Epoch 250/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0350
# Epoch 251/500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0393
# Epoch 252/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0686
# Epoch 253/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0433
# Epoch 254/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 255/500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0413
# Epoch 256/500
#  1/29 [>.............................] - ETA: 0s - loss: 0.0219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-1aff5b38c1a4> in <module>
#       2 model_input = np.concatenate([y.reshape(-1, 1), clusters_one_hot], axis=-1)
#       3 print(model_input.shape)
# ----> 4 model.fit(model_input, x, epochs=epochs)
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/localisation_from_image_project/envs/loc/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### B. test quality of $p(x|y,c,\epsilon)$ model

# %%
x_test, y_test, cluster_assignment_test, y_shifts = data['test']

# one-hot-encode cluster_assignment dataset
clusters_one_hot_test = np.zeros((cluster_assignment_test.size, cluster_assignment_test.max()+1))
clusters_one_hot_test[np.arange(cluster_assignment_test.size), cluster_assignment_test] = 1
model_input = np.concatenate([y_test.reshape(-1, 1), clusters_one_hot_test], axis=-1)

x_pred = model.predict(model_input)
plt.scatter(x_pred, y_test)
plt.title('ealuate quality of p(x|y,epsilon)')
plt.show()

# %% [markdown]
# ### C. Get p(y|x)

# %%
N_y = 4000
N_x = 4000
x_range = [-15,20]
y_range = [-8,8]

# %%
x_sample = -5
p_y_given_x = get_distribution_p_y_x(x_sample, model, num_sinusoids, y_shifts, y_range, N_y)

# %%
plot_p_y_x(p_y_given_x, y_range, N_y, y, x, x_sample)
# Out:
# <AxesSubplot:ylabel='x axis'>

# %% [markdown]
# ### Get a heatmap

# %%
x_queries = np.arange(x_range[0], x_range[1], (x_range[1] - x_range[0]) / N_x)
heat_map = get_heat_map_p_y_x(x_queries, model, num_sinusoids, y_shifts, y_range, N_y)

# %%
plot_heat_map(heat_map, x_range, y_range, N_x, N_y, tick_freq=1000)

# %% [markdown]
# # Our Localisation specific custom dataset

# %% [markdown]
# \begin{align}
# p(i,c,t,\epsilon) & = p(i|c,\epsilon)p(c|t)p(\epsilon; \sigma)p(t) \\
# p(t|i) & = \frac{\sum^C\sum^{\epsilon}{p(i,c,t,\epsilon)}}{\sum^T\sum^C\sum^{\epsilon}{p(i,c,t,\epsilon)}}
# \end{align}

# %% [markdown]
# $p(t)=Uniform(-100,100)$ - prior, fully defined
#
# $p(\epsilon; \sigma) = N(0,\epsilon) = N(0, 0.05)$ - prior, fully defined
#
# $p(c|t)$
#
# $p(i|c, \epsilon) = N(i; \mu(c), \sigma) = N(i; \mu(c), 0.05)$ - gaussian distirbution. Model parameters are $\mu(.)$ for each cluster *c*.

# %%
num_components = 10

# get dataset
data = get_dataset__simplified_localisation_problem(N=1000, C=100, num_clusters=num_components, one_to_many=True)
x, y, cluster_assignment, epsilon = data['train']
plot_dataset(x, y, cluster_assignment, title="Custom dataset")

# %% [markdown]
# ### get a NN model to approximate p(x|c ;epsilon)

# %%
model = simple_model(input_shape=num_components)

# %%
# one-hot-encode cluster_assignment dataset
clusters_one_hot = np.zeros((cluster_assignment.size, cluster_assignment.max()+1))
clusters_one_hot[np.arange(cluster_assignment.size), cluster_assignment] = 1

# %%
epochs = 50

model.fit(clusters_one_hot, x, epochs=epochs)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2707
# Epoch 2/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 3/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 4/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 5/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 6/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 7/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 8/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 9/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 10/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 11/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 12/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 13/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 14/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 15/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0106
# Epoch 16/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0113
# Epoch 17/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 18/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 19/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0113
# Epoch 20/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 21/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 22/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 23/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 24/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 25/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 26/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 27/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 28/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0116
# Epoch 29/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0114
# Epoch 30/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0106
# Epoch 31/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 32/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0111
# Epoch 33/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 34/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 35/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 36/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 37/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 38/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 39/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 40/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 41/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 42/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 43/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 44/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 45/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0109
# Epoch 46/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 47/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0109
# Epoch 48/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 49/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0111
# Epoch 50/50
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0107

# %% [markdown]
# ### Validate NN model

# %%
# visualise performance of the model. Do means for test set lie in the right clusters?
x_test, y_test, cluster_assignment_test, y_shifts = data['test']

# one-hot-encode cluster_assignment dataset
clusters_one_hot_test = np.zeros((cluster_assignment_test.size, cluster_assignment_test.max()+1))
clusters_one_hot_test[np.arange(cluster_assignment_test.size), cluster_assignment_test] = 1

x_pred = model.predict(clusters_one_hot_test)
plot_dataset(x_pred, y_test, cluster_assignment_test, title="Evaluate quality of NN model")

# %% [markdown]
# ### Specify some parameters for computation of conditional probability p(y|x)

# %%
# You have to manually specify ranges for x and y. 
# Just look at your dataset visualisation and choose ranges which encapsulate all x and y values
x_range = [-2,2]
y_range = [-110,110]

# number of points to evaluate posteriors for
N_y = 4000
N_x = 4000

# %%
# we need to specify begining and end of each cluster to define the prior p(c_i) = Uniform(c_mins[i], c_maxs[i])
c_mins = []
c_maxs = []
for i in range(num_components):
    y_max = y[cluster_assignment == i].max()
    y_min = y[cluster_assignment == i].min()
    c_mins.append(y_min)
    c_maxs.append(y_max)

# %% [markdown]
# ### Get and plot posterior p(y|x)

# %%
x_sample = [0.8]
probability_p_y_x = get_probability__custom_dataset(x_sample, model, num_components, y_range, N_y, c_mins=c_mins, c_maxs=c_maxs)

# %%
plot_probability(probability_p_y_x, y_range, N_y, y, x, x_sample, cluster_assignment)

# %% [markdown]
# ### Get and plot joint probability p(x,y)

# %%
x_queries = np.arange(x_range[0], x_range[1], (x_range[1] - x_range[0]) / N_x)
heat_map = get_probability__custom_dataset(x_queries, model, num_components, y_range, N_y, c_mins=c_mins, c_maxs=c_maxs)

# %%
plot_heat_map(heat_map, x_range, y_range, N_x, N_y, tick_freq=1000)
plt.show()
