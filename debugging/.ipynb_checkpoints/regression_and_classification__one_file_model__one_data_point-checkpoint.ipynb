# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
code_dir = "/home/mlmi-2020/jz522/localisation_from_image_project/code_reg_and_clas"
import os, sys
if code_dir not in sys.path:
    sys.path.append(code_dir)
    
from utilis.callbacks import Visualise_learning_reg_and_class

# %% [markdown]
# # Data Generator

# %%
class DataGenerator(keras.utils.Sequence):
    """ Loads, downsamples, crops, and auguments images and labels """
    
    def __init__(self, npz_file_IDs, batch_size=8, dim=(256,512), num_regions=20, shuffle=True, num_crops=1):

        self.npz_file_IDs = npz_file_IDs
        self.batch_size = batch_size
        self.dim = dim
        self.num_regions = num_regions
        self.shuffle = shuffle
        self.on_epoch_end()
        self.num_crops = num_crops

    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.npz_file_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
            
    def load_data(self, npz_file_ID_temp):
        """ Load .npz files with images and labels from self.room_dir """
        images = np.empty((self.batch_size, *self.dim, 3), dtype=np.float32)
        local_scene_coords = np.empty((self.batch_size, *self.dim, 3), dtype=np.float32)
        region_labels = np.empty((self.batch_size, *self.dim, 1), dtype=np.float32)
        masks = np.empty((self.batch_size, *self.dim, 1), dtype=np.int16)

        for i, ID in enumerate(npz_file_ID_temp):
            npz_data = np.load(ID)
            
            images[i] = npz_data['image_colors']
            local_scene_coords[i] = npz_data['local_scene_coords']
            region_labels[i] = np.expand_dims(npz_data['points_region_class'], axis=-1)
            masks[i] = np.expand_dims(npz_data['mask'], axis=-1).astype(int)

        return images, local_scene_coords, region_labels, masks

    
    def crop(self, data, start_row, start_col, data_depth):
        """ Images are equirectangular (360 projected onto a rectangle).
        Therefore we have to allow for all possibe crops, including these that run across the right image edge. """

        data_croped = np.zeros((self.batch_size, 224, 224, data_depth))

        for ind in range(self.batch_size):

            if start_col[ind] + 224 > 512:
                dif = start_col[ind] + 224 - 512
                wraped_data = data[ind, start_row[ind]:start_row[ind]+224, :dif,:]
                
                data_croped[ind] = np.concatenate(
                    (data[ind, start_row[ind]:start_row[ind]+224, start_col[ind]:start_col[ind]+224,:], 
                        wraped_data), axis=1)
                               
            else:
                data_croped[ind] = data[ind, start_row[ind]:start_row[ind]+224, start_col[ind]:start_col[ind]+224,:]

        return data_croped
    
    
    def get_crops(self, images, coords, regions, mask):
        
        # pick the start cordinates of croped images
        start_row = [0] #np.random.randint(0, high=self.dim[0]-224, size=self.batch_size)
        start_col = [50] # np.random.randint(0, high=self.dim[1], size=self.batch_size)
        
        image_crops = self.crop(images, start_row, start_col, data_depth=3)
        coords_crops = self.crop(coords, start_row, start_col, data_depth=3)
        region_crops = self.crop(regions, start_row, start_col, data_depth=1)
        mask_crops = self.crop(mask, start_row, start_col, data_depth=1)
        
        return image_crops, coords_crops, region_crops, mask_crops
    
    
    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.npz_file_IDs) / self.batch_size))
    
     
    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.npz_file_IDs[k] for k in indexes]

        # load
        images, local_scene_coords, region_labels, masks = self.load_data(list_IDs_temp)

        # crop
        images, local_scene_coords, region_labels, masks = self.get_crops(images, local_scene_coords, region_labels, masks)

        
        # one-hot encode labels
#         region_labels = (np.arange(self.num_regions) == region_labels[:,:,:,0][...,None]).astype(int)


        # expand dimension of mask
        nested_masks = [masks for _ in range(3)]
        mask_expanded = np.concatenate(nested_masks, axis=-1)

        # apply mask to 3D coords ground truth data
        local_scene_coords = local_scene_coords * mask_expanded
                               
        # coccatenate to images
        labels = np.concatenate((local_scene_coords, region_labels), axis=-1)

        return [images, mask_expanded], labels

# %%
# dataset_size = 370
# val_split = 0.1
# data_dir = "/data/cornucopia/jz522/localisation_project/DS_003_JDB-Full/coordinates_256_512_complete_working_141_classes/"

# data_partition = {'train': [],
#                 'validation': []}

# indexes = np.arange(1,dataset_size + 1)
# np.random.shuffle(indexes)
# split_index = int(val_split*dataset_size)

# for ind in indexes[split_index:]:
#     coord_npz = f"{ind:04}_rendered.png_config.npz"
#     data_partition['train'].append(data_dir + coord_npz)

# for ind in indexes[:split_index]:
#     coord_npz = f"{ind:04}_rendered.png_config.npz"
#     data_partition['validation'].append(data_dir + coord_npz)

# %%
generator_configs = {'batch_size': 1, 
                     'dim': (256,512),
                     'num_regions': 141, 
                     'shuffle': True, 
                     'num_crops': 1}

data_partition = ["/data/cornucopia/jz522/localisation_project/DS_003_JDB-Full/coordinates_256_512_complete_working_141_classes/0001_rendered.png_config.npz"]

train_generator = DataGenerator(data_partition, **generator_configs)

# %% [markdown]
# # Model

# %%
from tensorflow.keras import layers

def vgg_encoder(input_shape=(224, 224, 3)):
    
    image_input = layers.Input(shape=(224, 224, 3))

    # Block 1
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(image_input)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)
    f1 = x
    
    # Block 2
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)
    f2 = x
    
    # Block 3
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)
    f3 = x

    # Block 4
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)
    f4 = x
  
    return image_input, [f1,f2,f3,f4]

# %%
from tensorflow.keras.models import Model

def vgg_unet(num_regions, input_height=224, input_width=224):

    model = unet(vgg_encoder, num_regions, input_height=input_height, input_width=input_width)
    model.model_name = "vgg_unet"
    
    return model


def unet(encoder, num_regions, l1_skip_conn=True, input_height=224,
          input_width=224):

    image_input = layers.Input(shape=(224, 224, 3))
    mask = layers.Input(shape=(224, 224, 3))
    
    image_input, levels = encoder(image_input)
    [f1, f2, f3, f4] = levels

    o = f4
    o = (layers.ZeroPadding2D((1, 1), name='U_block1_zero_pad'))(o)
    o = (layers.Conv2D(512, (3, 3), padding='valid' , activation='relu', name='U_block1_conv'))(o)
    o = (layers.BatchNormalization(name='U_block1_batch_norm'))(o)

    o = (layers.UpSampling2D((2, 2), name='U_block2_up_sample'))(o)
    o = (layers.concatenate([o, f3], axis=-1, name='U_block2_concat'))
    o = (layers.ZeroPadding2D((1, 1)))(o)
    o = (layers.Conv2D(512, (3, 3), padding='valid', activation='relu'))(o)
    o = (layers.BatchNormalization())(o)

    o = (layers.UpSampling2D((2, 2)))(o)
    o = (layers.concatenate([o, f2], axis=-1))
    o = (layers.ZeroPadding2D((1, 1)))(o)
    o = (layers.Conv2D(256, (3, 3), padding='valid' , activation='relu'))(o)
    o = (layers.BatchNormalization())(o)

    o = (layers.UpSampling2D((2, 2)))(o)

    if l1_skip_conn:
        o = (layers.concatenate([o, f1], axis=-1))

    o = (layers.ZeroPadding2D((1, 1)))(o)
    o = (layers.Conv2D(128, (3, 3), padding='valid', activation='relu'))(o)
    o = (layers.BatchNormalization())(o)

    o = layers.Conv2D(128, (3, 3), padding='same')(o)
    
    o = (layers.UpSampling2D((2, 2)))(o)
    o = (layers.ZeroPadding2D((1, 1)))(o)
    o = (layers.Conv2D(64, (3, 3), padding='valid', activation='relu'))(o)
    o = (layers.BatchNormalization())(o)
    

    
    # REGRESSION
#     o_regr = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(o)
    output_reg = layers.Conv2D(3, (3, 3), padding='same')(o)
    output_masked_reg = layers.Multiply()([output_reg, mask])

    
    # CLASSIFICATION
    o_clas = layers.Conv2D(num_regions, (3, 3), padding='same')(o)
    output_clas = keras.activations.softmax(o_clas, axis=-1)
    
    
    # CONCATENATE
    output = layers.Concatenate(axis=-1)([output_masked_reg, output_clas])
    
    
    model = Model(inputs=[image_input, mask], outputs=output) 
#     model.summary()
    
    return model

# %% [markdown]
# # MSE metric

# %%
def scene_coord_regression_metric(y_true, y_pred):
    
    # 1. convert regions to their mean centers
    # 2. unwhitten local coordinates
    # 3. add regions centers to local coordinates (pixelwise) to get global scene coordinates
    # 4. compute MSE
    
    # This could be easily done in a callback - because there i can simply store all the files i need to store

# %% [markdown]
# # MSE callback

# %%
class pixelwise_MSE(keras.callbacks.Callback):
    def __init__(self, datapoint_name, frequency, start_row=[0], start_col=[50]):
        super(pixelwise_MSE, self).__init__()
        
        data = self.load_data(datapoint_name, start_row, start_col)
        
        self.image = data['image']
        self.oracle_global_coords = data['points_3d_world']  # i will use this to check whether i'm converting the data correctly
        self.mask = data['mask']
        self.W_inv = data['W_inv']
        self.M = data['M']
        self.std = data['std']
        
        self.frequency = frequency
        
        
      
    def crop(self, data, start_row, start_col, data_depth):
        num_crops = len(start_row)
        data_croped = np.zeros((num_crops, 224, 224, data_depth))

        for ind in range(num_crops):
            if start_col[ind] + 224 > 512:
                dif = start_col[ind] + 224 - 512
                wraped_data = data[ind, start_row[ind]:start_row[ind]+224, :dif,:]
                
                data_croped[ind] = np.concatenate(
                    (data[ind, start_row[ind]:start_row[ind]+224, start_col[ind]:start_col[ind]+224,:], 
                        wraped_data), axis=1)  
            else:
                data_croped[ind] = data[ind, start_row[ind]:start_row[ind]+224, start_col[ind]:start_col[ind]+224,:]

        return data_croped
    
    
    def load_data(self, data_filename, start_row, start_col):
        data = np.load(data_filename)

        image = self.crop(  np.expand_dims(data['image_colors'], axis=0), start_row, start_col, 3)
        points_3d_world = self.crop(  np.expand_dims(data['points_3d_world'], axis=0), start_row, start_col, 3)
        mask = self.crop(  np.expand_dims(data['mask'], axis=[0,-1]), start_row, start_col, 1)
        
        W_inv = data['W_inv']
        M = data['M']
        std = data['std']
        
        
        return {'image': image,
                'points_3d_world': points_3d_world, 
                'mask': mask,
                'W_inv': W_inv,
                'M': M, 
                'std': std}
    
        
    def on_epoch_end(self, epoch, logs=None):
        if(epoch%self.frequency == 0):

            output = self.model.predict([self.image, self.mask])
            global_coords = np.zeros((224*224,3))
            
            # 1. convert regions to their mean centers
            pred_local_coords = np.reshape(output[:,:,:,:3], (-1,3))
            labels = np.argmax(output[:,:,:,3:], axis=-1)
            pred_regions = np.reshape(labels, (-1)).astype(int)
                       
          
            # 2. unwhitten local coordinates
            for region in np.unique(pred_regions):
                region_coords = pred_local_coords[pred_regions == region]
                unwhite_loc_coords = np.dot(region_coords * self.std[region] , self.W_inv[region]) + self.M[region]
                
                global_coords[pred_regions == region] = unwhite_loc_coords
            
           
            # 4. compute MSE
            global_coords = np.reshape(global_coords, (224,224,3))
            global_coords = global_coords * self.mask[0]
            oracle = self.oracle_global_coords[0] * self.mask[0]
            euc_dist = np.mean(np.square(oracle - global_coords), axis=-1)
            print('\n', 'MSE: ', np.mean(euc_dist))
            
            
            # 5. plot for visualisation
            
#             fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(16,3))
#             region_centers = M[pred_regions]
#             max_ = max(self.oracle_global_coords[0].max(), global_coords.max())
#             min_ = min(self.oracle_global_coords[0].min(), global_coords.min())
            
#             oracle_coords_norm = (self.oracle_global_coords[0] - min_) / (max_ - min_)
#             ax1.imshow(oracle_coords_norm)
#             ax1.set_title("Ground truth - global scene coords")
            
#             pred_coords_norm = (global_coords - min_) / (max_ - min_)
#             ax2.imshow(pred_coords_norm)
#             ax2.set_title("Pred - global scene coords")
            
#             region_centers = np.reshape(region_centers, (224,224,3))
# #             reg_cent_norm = (region_centers - min_) / (max_ - min_)
#             ax3.imshow(region_centers)
            
#             im4 = ax4.imshow(euc_dist)
#             ax4.set_title("Euclidean distance")
            
#             divider = make_axes_locatable(ax4)
#             cax = divider.append_axes('right', size='5%', pad=0.1)
#             cbar = fig.colorbar(im4, cax=cax)

#             plt.show()

# %% [markdown]
# # Loss func

# %%
def combined_loss(y_true, y_pred):
    " combined loss for 3D local coordinate regression and Classification"

    beta = 0.5
    
    regr_true = y_true[:,:,:,:3]
    clas_true = y_true[:,:,:,3:]    
    regr_pred = y_pred[:,:,:,:3]
    clas_pred = y_pred[:,:,:,3:]

    regr_loss = tf.keras.losses.mean_squared_error(regr_true, regr_pred)
    regr_loss = tf.reduce_mean(regr_loss)

#     clas_loss = tf.keras.losses.categorical_crossentropy(clas_true, clas_pred)  # 1-hot-encoded labels
    clas_loss = tf.keras.losses.sparse_categorical_crossentropy(clas_true, clas_pred)  # categorical labels 
    clas_loss = tf.reduce_mean(clas_loss)
    
    loss = 1*regr_loss + 1*clas_loss
    return loss

# %% [markdown]
# # Setup model

# %%
# Example model
unet_model = vgg_unet(num_regions=141)
unet_model.compile(optimizer=keras.optimizers.Adam(5e-4), loss=combined_loss)

# %% [markdown]
# # Fit model

# %%
[images, mask], labels = train_generator.__getitem__(0)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(16,3))

ax1.imshow(images[0])
ax1.set_title("input image")

ax2.imshow(mask[0,:,:,0])
ax2.set_title("mask")

# only use two lines below if input is unnormalised
local_coords_norm = (labels[0,:,:,:3] - labels[0,:,:,:3].min()) / (labels[0,:,:,:3].max() - labels[0,:,:,:3].min())
ax3.imshow(local_coords_norm)
ax3.set_title("local scene coords")

# ax4.imshow(np.argmax(labels[0,:,:,3:], axis=-1))
ax4.imshow(labels[0,:,:,3:])
ax4.set_title("region labels")
plt.show()

# %%
np.unique(labels[0,:,:,3:])
# Out:
# array([  0.,   1.,   4.,   5.,   6.,   7.,   8.,   9., 140.])

# %% [markdown]
# **Note:** you can see mask on visualisation of local scene coords. The mask has been already applied in the data generator. In prediction visualisation mask will also have been applied in the network.

# %% [markdown]
# **Note2:** it is VERY IMPORTANT to have normalised labels. Otherwise it is harder to optimise the model (i wasn't able to train it).

# %%
file_name = "/data/cornucopia/jz522/localisation_project/DS_003_JDB-Full/coordinates_256_512_complete_working_141_classes/0001_rendered.png_config.npz"
global_coord_mse_callback = pixelwise_MSE(file_name, 1)
train_vis = Visualise_learning_reg_and_class(images[0], mask[0], labels[0,:,:,:3], labels[0,:,:,3:], 
                                            50, "temp_testing", "train/")

callbacks = [global_coord_mse_callback] # [train_vis,

# %%
fit_configs = {'epochs': 300, 
               'verbose': 1}

history = unet_model.fit([images, mask], labels, callbacks=[callbacks], **fit_configs) #, callbacks=callback
# Out:
#  ###     TRAIN      ###
# Epoch 1/501
# 1/1 [==============================] - ETA: 0s - loss: 8.2107WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_23:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 224, 224, 1).
# WARNING:tensorflow:5 out of the last 110 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4da459eb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  MSE:  82.64629573903638
# 1/1 [==============================] - 1s 990ms/step - loss: 8.2107
# Epoch 2/501
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4327
# Epoch 3/501
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4336
# Epoch 4/501
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3153
# Epoch 5/501
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7951
# Epoch 6/501
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4804
# Epoch 7/501
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2305
# Epoch 8/501
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9830
# Epoch 9/501
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7533
# Epoch 10/501
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5212
# Epoch 11/501
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2914
# Epoch 12/501
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0688
# Epoch 13/501
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8505
# Epoch 14/501
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6321
# Epoch 15/501
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4166
# Epoch 16/501
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2067
# Epoch 17/501
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0069
# Epoch 18/501
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8217
# Epoch 19/501
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6525
# Epoch 20/501
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4872
# Epoch 21/501
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3459
# Epoch 22/501
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2110
# Epoch 23/501
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1393
# Epoch 24/501
# 1/1 [==============================] - 0s 904us/step - loss: 1.1063
# Epoch 25/501
# 1/1 [==============================] - 0s 926us/step - loss: 0.9640
# Epoch 26/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8653
# Epoch 27/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8073
# Epoch 28/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7396
# Epoch 29/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6954
# Epoch 30/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6453
# Epoch 31/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5982
# Epoch 32/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5655
# Epoch 33/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5274
# Epoch 34/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4992
# Epoch 35/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4678
# Epoch 36/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4424
# Epoch 37/501
# 1/1 [==============================] - 0s 988us/step - loss: 0.4189
# Epoch 38/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4124
# Epoch 39/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3820
# Epoch 40/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3552
# Epoch 41/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3438
# Epoch 42/501
# 1/1 [==============================] - 0s 990us/step - loss: 0.3235
# Epoch 43/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3071
# Epoch 44/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2879
# Epoch 45/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2760
# Epoch 46/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2742
# Epoch 47/501
# 1/1 [==============================] - 0s 790us/step - loss: 0.2999
# Epoch 48/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3146
# Epoch 49/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2514
# Epoch 50/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2620
#
#  ###     TRAIN      ###
# Epoch 51/501
# 1/1 [==============================] - ETA: 0s - loss: 0.2472
#  MSE:  101.07236509328709
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 739ms/step - loss: 0.2472
# Epoch 52/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2308
# Epoch 53/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2200
# Epoch 54/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2064
# Epoch 55/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1985
# Epoch 56/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1935
# Epoch 57/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1787
# Epoch 58/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1783
# Epoch 59/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1667
# Epoch 60/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1642
# Epoch 61/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1554
# Epoch 62/501
# 1/1 [==============================] - 0s 964us/step - loss: 0.1521
# Epoch 63/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1449
# Epoch 64/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1423
# Epoch 65/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1383
# Epoch 66/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1349
# Epoch 67/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1309
# Epoch 68/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1249
# Epoch 69/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1239
# Epoch 70/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1203
# Epoch 71/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1192
# Epoch 72/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1134
# Epoch 73/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1112
# Epoch 74/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1092
# Epoch 75/501
# 1/1 [==============================] - 0s 962us/step - loss: 0.1084
# Epoch 76/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1041
# Epoch 77/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1019
# Epoch 78/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1011
# Epoch 79/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1002
# Epoch 80/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0977
# Epoch 81/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0938
# Epoch 82/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0931
# Epoch 83/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0920
# Epoch 84/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0894
# Epoch 85/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 86/501
# 1/1 [==============================] - 0s 982us/step - loss: 0.0871
# Epoch 87/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0855
# Epoch 88/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0834
# Epoch 89/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0821
# Epoch 90/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0817
# Epoch 91/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0820
# Epoch 92/501
# 1/1 [==============================] - 0s 998us/step - loss: 0.0859
# Epoch 93/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0895
# Epoch 94/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0957
# Epoch 95/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0886
# Epoch 96/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1016
# Epoch 97/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0967
# Epoch 98/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0901
# Epoch 99/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0919
# Epoch 100/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0857
#
#  ###     TRAIN      ###
# Epoch 101/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0865
#  MSE:  12.663891651450673
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 805ms/step - loss: 0.0865
# Epoch 102/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0824
# Epoch 103/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0805
# Epoch 104/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0795
# Epoch 105/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0767
# Epoch 106/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0755
# Epoch 107/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0745
# Epoch 108/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0721
# Epoch 109/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0718
# Epoch 110/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0731
# Epoch 111/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0700
# Epoch 112/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0714
# Epoch 113/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 114/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0651
# Epoch 115/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0657
# Epoch 116/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0640
# Epoch 117/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0627
# Epoch 118/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0613
# Epoch 119/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0613
# Epoch 120/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 121/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0590
# Epoch 122/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0580
# Epoch 123/501
# 1/1 [==============================] - 0s 998us/step - loss: 0.0579
# Epoch 124/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0566
# Epoch 125/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0557
# Epoch 126/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0553
# Epoch 127/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0549
# Epoch 128/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0539
# Epoch 129/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0533
# Epoch 130/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0526
# Epoch 131/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0524
# Epoch 132/501
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0521
# Epoch 133/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 134/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 135/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0523
# Epoch 136/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0534
# Epoch 137/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0562
# Epoch 138/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0571
# Epoch 139/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0593
# Epoch 140/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0547
# Epoch 141/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0496
# Epoch 142/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0485
# Epoch 143/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0508
# Epoch 144/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0506
# Epoch 145/501
# 1/1 [==============================] - 0s 962us/step - loss: 0.0471
# Epoch 146/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0467
# Epoch 147/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0479
# Epoch 148/501
# 1/1 [==============================] - 0s 875us/step - loss: 0.0459
# Epoch 149/501
# 1/1 [==============================] - 0s 951us/step - loss: 0.0445
# Epoch 150/501
# 1/1 [==============================] - 0s 954us/step - loss: 0.0454
#
#  ###     TRAIN      ###
# Epoch 151/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0453
#  MSE:  0.7707377079537876
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 734ms/step - loss: 0.0453
# Epoch 152/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0444
# Epoch 153/501
# 1/1 [==============================] - 0s 980us/step - loss: 0.0442
# Epoch 154/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0449
# Epoch 155/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0440
# Epoch 156/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0432
# Epoch 157/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0437
# Epoch 158/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0432
# Epoch 159/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0415
# Epoch 160/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0413
# Epoch 161/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0414
# Epoch 162/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0408
# Epoch 163/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0404
# Epoch 164/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0400
# Epoch 165/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0399
# Epoch 166/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0399
# Epoch 167/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0395
# Epoch 168/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0399
# Epoch 169/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0407
# Epoch 170/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0418
# Epoch 171/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0432
# Epoch 172/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0444
# Epoch 173/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 174/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0396
# Epoch 175/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0379
# Epoch 176/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0389
# Epoch 177/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0409
# Epoch 178/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0403
# Epoch 179/501
# 1/1 [==============================] - 0s 966us/step - loss: 0.0397
# Epoch 180/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0393
# Epoch 181/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0388
# Epoch 182/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 183/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0367
# Epoch 184/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0367
# Epoch 185/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0371
# Epoch 186/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0358
# Epoch 187/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0350
# Epoch 188/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0355
# Epoch 189/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0352
# Epoch 190/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 191/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0337
# Epoch 192/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 193/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 194/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 195/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0327
# Epoch 196/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 197/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 198/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0321
# Epoch 199/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0322
# Epoch 200/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0328
#
#  ###     TRAIN      ###
# Epoch 201/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0338
#  MSE:  0.1522405599252221
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 729ms/step - loss: 0.0338
# Epoch 202/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0352
# Epoch 203/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0388
# Epoch 204/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0417
# Epoch 205/501
# 1/1 [==============================] - 0s 941us/step - loss: 0.0465
# Epoch 206/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0504
# Epoch 207/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0548
# Epoch 208/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0455
# Epoch 209/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0531
# Epoch 210/501
# 1/1 [==============================] - 0s 855us/step - loss: 0.0487
# Epoch 211/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0531
# Epoch 212/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0473
# Epoch 213/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0459
# Epoch 214/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0421
# Epoch 215/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0419
# Epoch 216/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0401
# Epoch 217/501
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0383
# Epoch 218/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0392
# Epoch 219/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0371
# Epoch 220/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0359
# Epoch 221/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0365
# Epoch 222/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 223/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 224/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0338
# Epoch 225/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0325
# Epoch 226/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0324
# Epoch 227/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0323
# Epoch 228/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0316
# Epoch 229/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0313
# Epoch 230/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0310
# Epoch 231/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0303
# Epoch 232/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0298
# Epoch 233/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0294
# Epoch 234/501
# 1/1 [==============================] - 0s 970us/step - loss: 0.0289
# Epoch 235/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0290
# Epoch 236/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 237/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0285
# Epoch 238/501
# 1/1 [==============================] - 0s 951us/step - loss: 0.0280
# Epoch 239/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0279
# Epoch 240/501
# 1/1 [==============================] - 0s 873us/step - loss: 0.0274
# Epoch 241/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 242/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 243/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 244/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 245/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 246/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0262
# Epoch 247/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0261
# Epoch 248/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0258
# Epoch 249/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0257
# Epoch 250/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0255
#
#  ###     TRAIN      ###
# Epoch 251/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0254
#  MSE:  0.10284413700827875
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 713ms/step - loss: 0.0254
# Epoch 252/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 253/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 254/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 255/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 256/501
# 1/1 [==============================] - 0s 924us/step - loss: 0.0257
# Epoch 257/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 258/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0314
# Epoch 259/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0388
# Epoch 260/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0482
# Epoch 261/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0398
# Epoch 262/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 263/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 264/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0322
# Epoch 265/501
# 1/1 [==============================] - 0s 929us/step - loss: 0.0289
# Epoch 266/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0294
# Epoch 267/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0297
# Epoch 268/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 269/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 270/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 271/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 272/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0261
# Epoch 273/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 274/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 275/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 276/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 277/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0242
# Epoch 278/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0248
# Epoch 279/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0242
# Epoch 280/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 281/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 282/501
# 1/1 [==============================] - 0s 994us/step - loss: 0.0236
# Epoch 283/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 284/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 285/501
# 1/1 [==============================] - 0s 919us/step - loss: 0.0228
# Epoch 286/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 287/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 288/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0225
# Epoch 289/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 290/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 291/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 292/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 293/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 294/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0242
# Epoch 295/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0247
# Epoch 296/501
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0247
# Epoch 297/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 298/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0215
# Epoch 299/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0218
# Epoch 300/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0224
#
#  ###     TRAIN      ###
# Epoch 301/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0219
#  MSE:  0.07085792388847001
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 735ms/step - loss: 0.0219
# Epoch 302/501
# 1/1 [==============================] - 0s 934us/step - loss: 0.0213
# Epoch 303/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 304/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0213
# Epoch 305/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0213
# Epoch 306/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0210
# Epoch 307/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0206
# Epoch 308/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 309/501
# 1/1 [==============================] - 0s 967us/step - loss: 0.0208
# Epoch 310/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0206
# Epoch 311/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0202
# Epoch 312/501
# 1/1 [==============================] - 0s 940us/step - loss: 0.0202
# Epoch 313/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0202
# Epoch 314/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0202
# Epoch 315/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0200
# Epoch 316/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0199
# Epoch 317/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0198
# Epoch 318/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0197
# Epoch 319/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0196
# Epoch 320/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0196
# Epoch 321/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0196
# Epoch 322/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0195
# Epoch 323/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0195
# Epoch 324/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0197
# Epoch 325/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0202
# Epoch 326/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0214
# Epoch 327/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0226
# Epoch 328/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0239
# Epoch 329/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 330/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0220
# Epoch 331/501
# 1/1 [==============================] - 0s 810us/step - loss: 0.0210
# Epoch 332/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0208
# Epoch 333/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0208
# Epoch 334/501
# 1/1 [==============================] - 0s 872us/step - loss: 0.0202
# Epoch 335/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0195
# Epoch 336/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0195
# Epoch 337/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0198
# Epoch 338/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0195
# Epoch 339/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 340/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0188
# Epoch 341/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 342/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 343/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0185
# Epoch 344/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 345/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 346/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0184
# Epoch 347/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 348/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 349/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 350/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0181
#
#  ###     TRAIN      ###
# Epoch 351/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0180
#  MSE:  0.05785055080304209
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 716ms/step - loss: 0.0180
# Epoch 352/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0178
# Epoch 353/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0177
# Epoch 354/501
# 1/1 [==============================] - 0s 957us/step - loss: 0.0177
# Epoch 355/501
# 1/1 [==============================] - 0s 949us/step - loss: 0.0177
# Epoch 356/501
# 1/1 [==============================] - 0s 966us/step - loss: 0.0176
# Epoch 357/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0175
# Epoch 358/501
# 1/1 [==============================] - 0s 872us/step - loss: 0.0175
# Epoch 359/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0177
# Epoch 360/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 361/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0186
# Epoch 362/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0200
# Epoch 363/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 364/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 365/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 366/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0315
# Epoch 367/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0260
# Epoch 368/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 369/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0258
# Epoch 370/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0261
# Epoch 371/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0254
# Epoch 372/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0225
# Epoch 373/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0227
# Epoch 374/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0210
# Epoch 375/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0216
# Epoch 376/501
# 1/1 [==============================] - 0s 954us/step - loss: 0.0206
# Epoch 377/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0207
# Epoch 378/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 379/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0197
# Epoch 380/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 381/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 382/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0192
# Epoch 383/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 384/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0184
# Epoch 385/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 386/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0178
# Epoch 387/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0175
# Epoch 388/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0174
# Epoch 389/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 390/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 391/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 392/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 393/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 394/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 395/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0165
# Epoch 396/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0164
# Epoch 397/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 398/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0162
# Epoch 399/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 400/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0160
#
#  ###     TRAIN      ###
# Epoch 401/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0159
#  MSE:  0.03380900716542891
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 733ms/step - loss: 0.0159
# Epoch 402/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0158
# Epoch 403/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0158
# Epoch 404/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0157
# Epoch 405/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0156
# Epoch 406/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 407/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 408/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0154
# Epoch 409/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0154
# Epoch 410/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 411/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 412/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 413/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 414/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 415/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0151
# Epoch 416/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 417/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 418/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 419/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0163
# Epoch 420/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 421/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 422/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0210
# Epoch 423/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0208
# Epoch 424/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0198
# Epoch 425/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0187
# Epoch 426/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0176
# Epoch 427/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 428/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0166
# Epoch 429/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 430/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0165
# Epoch 431/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 432/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0156
# Epoch 433/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 434/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0158
# Epoch 435/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 436/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0148
# Epoch 437/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0150
# Epoch 438/501
# 1/1 [==============================] - 0s 982us/step - loss: 0.0154
# Epoch 439/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 440/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0144
# Epoch 441/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 442/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 443/501
# 1/1 [==============================] - 0s 961us/step - loss: 0.0144
# Epoch 444/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 445/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 446/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 447/501
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 448/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 449/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 450/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0144
#
#  ###     TRAIN      ###
# Epoch 451/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0145
#  MSE:  0.02806412815780209
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 1s/step - loss: 0.0145
# Epoch 452/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0148
# Epoch 453/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 454/501
# 1/1 [==============================] - 0s 980us/step - loss: 0.0165
# Epoch 455/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 456/501
# 1/1 [==============================] - 0s 901us/step - loss: 0.0181
# Epoch 457/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0171
# Epoch 458/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0154
# Epoch 459/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 460/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0146
# Epoch 461/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0153
# Epoch 462/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0150
# Epoch 463/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 464/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 465/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 466/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 467/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 468/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 469/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0139
# Epoch 470/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 471/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 472/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 473/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0136
# Epoch 474/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 475/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 476/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 477/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0144
# Epoch 478/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0157
# Epoch 479/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0171
# Epoch 480/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0188
# Epoch 481/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0183
# Epoch 482/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0166
# Epoch 483/501
# 1/1 [==============================] - 0s 839us/step - loss: 0.0147
# Epoch 484/501
# 1/1 [==============================] - 0s 884us/step - loss: 0.0142
# Epoch 485/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 486/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 487/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 488/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 489/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 490/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 491/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 492/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 493/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 494/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0132
# Epoch 495/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 496/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 497/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0133
# Epoch 498/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 499/501
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 500/501
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0130
#
#  ###     TRAIN      ###
# Epoch 501/501
# 1/1 [==============================] - ETA: 0s - loss: 0.0131
#  MSE:  0.020696680274112773
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 1s 801ms/step - loss: 0.0131

# %% [markdown]
# # Evaluate model

# %%
label_pred = unet_model.predict([images, mask])

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(16,3))

ax1.imshow(images[0])
ax1.set_title("input image")

ax2.imshow(mask[0,:,:,0])
ax2.set_title("mask")

tmp = (label_pred[0,:,:,:3] - label_pred[0,:,:,:3].min()) / (label_pred[0,:,:,:3].max() - label_pred[0,:,:,:3].min())
ax3.imshow(tmp)
ax3.set_title("local scene coords (normalised)")

ax4.imshow(np.argmax(label_pred[0,:,:,3:], axis=-1))
ax4.set_title("region labels")
plt.show()

# %%
# visualise distribution of TRUE and PRED
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,3))

ax1.hist(np.reshape(label_pred[0,:,:,:3], (-1)), label="pred", alpha=0.3)
ax1.hist(np.reshape(labels[0,:,:,:3], (-1)), label="true", alpha=0.3)
ax1.set_title('regression')
ax1.legend()

ax2.hist(np.reshape(np.argmax(label_pred[0,:,:,3:], axis=-1), (-1)), label="pred", alpha=0.3, bins=20)
# ax2.hist(np.reshape(np.argmax(labels[0,:,:,3:], axis=-1), (-1)), label="true", alpha=0.3)
ax2.hist(np.reshape(labels[0,:,:,3:], (-1)), label="true", alpha=0.3, bins=20)
ax2.set_title('classification')
ax2.legend()
plt.show()

# %% [markdown]
# # Unwhiten predicted coordinates

# %% [markdown]
# # Predict pose

# %% [markdown]
# # Debugging code

# %% [markdown]
# ### getting outputs of individual layers

# %%
extractor = keras.Model(inputs=unet_model.inputs,
                        outputs=[unet_model.output for layer in unet_model.layers])

# %%
output = extractor(images)
output[-1].numpy()[0,0,0,:]

# %% [markdown]
# ### test loss function utside of NN

# %%
gen_mask_ = np.expand_dims(gen_mask, axis=-1)
gen_mask_.shape
# Out:
# (1, 224, 224, 1)

# %%
labels_pred = np.zeros((1,224,224,8))
labels_pred[:,:,:,:] = 1/8

labels_true = np.zeros((1,224,224,8))
labels_true[:,:,:,0] = 1
# mask = np.ones((1,224,224,1))
labels_true = np.concatenate([labels_true, gen_mask_], axis=-1)
labels_true.shape
# Out:
# (1, 224, 224, 9)

# %%
a = masked_X_entropy(labels_true, labels_pred)
a.numpy()
# Out:
# tf.Tensor(
# [[[2.07944154 2.07944154 2.07944154 ... 2.07944154 2.07944154 2.07944154]
#   [2.07944154 2.07944154 2.07944154 ... 2.07944154 2.07944154 2.07944154]
#   [2.07944154 2.07944154 2.07944154 ... 2.07944154 2.07944154 2.07944154]
#   ...
#   [2.07944154 2.07944154 2.07944154 ... 2.07944154 2.07944154 2.07944154]
#   [2.07944154 2.07944154 2.07944154 ... 2.07944154 2.07944154 2.07944154]
#   [2.07944154 2.07944154 2.07944154 ... 2.07944154 2.07944154 2.07944154]]], shape=(1, 224, 224), dtype=float64)
# array([[[2.07944154, 2.07944154, 2.07944154, ..., 2.07944154,
#          2.07944154, 2.07944154],
#         [2.07944154, 2.07944154, 2.07944154, ..., 2.07944154,
#          2.07944154, 2.07944154],
#         [2.07944154, 2.07944154, 2.07944154, ..., 2.07944154,
#          2.07944154, 2.07944154],
#         ...,
#         [2.07944154, 2.07944154, 2.07944154, ..., 2.07944154,
#          2.07944154, 2.07944154],
#         [2.07944154, 2.07944154, 2.07944154, ..., 2.07944154,
#          2.07944154, 2.07944154],
#         [2.07944154, 2.07944154, 2.07944154, ..., 2.07944154,
#          2.07944154, 2.07944154]]])

# %%
np.unique(a.numpy())
# Out:
# array([0.        , 2.07944154])

# %%
plt.hist(a.numpy().flatten())
# Out:
# (array([2.4000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 5.0152e+04]),
#  array([0.        , 0.20794415, 0.41588831, 0.62383246, 0.83177662,
#         1.03972077, 1.24766493, 1.45560908, 1.66355323, 1.87149739,
#         2.07944154]),
#  <BarContainer object of 10 artists>)

# %%
tf.keras.losses.categorical_crossentropy(labels_pred, labels_true[:,:,:,:8])
# Out:
# <tf.Tensor: shape=(1, 224, 224), dtype=float64, numpy=
# array([[[14.10333371, 14.10333371, 14.10333371, ..., 14.10333371,
#          14.10333371, 14.10333371],
#         [14.10333371, 14.10333371, 14.10333371, ..., 14.10333371,
#          14.10333371, 14.10333371],
#         [14.10333371, 14.10333371, 14.10333371, ..., 14.10333371,
#          14.10333371, 14.10333371],
#         ...,
#         [14.10333371, 14.10333371, 14.10333371, ..., 14.10333371,
#          14.10333371, 14.10333371],
#         [14.10333371, 14.10333371, 14.10333371, ..., 14.10333371,
#          14.10333371, 14.10333371],
#         [14.10333371, 14.10333371, 14.10333371, ..., 14.10333371,
#          14.10333371, 14.10333371]]])>

# %% [markdown]
# ## $\color{red}{\text{CONCLUSION:}}$
# ### there were 3 errors:
#
# **1. cross entropy outputed 2D matrix rather than scalar** Loss in general should be a scalar. If it's a vector you might compute an update with respect to each element of loss which could grow quicker than for a mean. There would be batch_size*224*224 updates
#
# **2. I was applying softmax function twice** After deleting the first softmax model was fixed. The first softmax could be applied for all nodes 224x224x8 rather than just along the axis=-1
#
# **3. there is some issue with the way i apply the mask**
