# %%
import numpy as np
import json
import matplotlib.pyplot as plt
from tqdm import tqdm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
code_dir = "/home/mlmi-2020/jz522/localisation_from_image_project/code_reg_and_clas"
import os, sys
if code_dir not in sys.path:
    sys.path.append(code_dir)

# %% [markdown]
# ## load data

# %%
# load dataset
data_dir = "/data/cornucopia/jz522/localisation_project/DS_003_JDB-Full/coordinates_256_512_complete_working_141_classes/"
dataset_size = 370
start = 0


images = np.zeros((dataset_size, 256, 512, 3))
oracle_global_coords = np.zeros((dataset_size, 256, 512, 3))
regions = np.zeros((dataset_size, 256, 512, 1))
local_coords = np.zeros((dataset_size, 256, 512, 3))
masks = np.zeros((dataset_size, 256, 512, 1))

for i in tqdm(np.arange(start, start+dataset_size)):
    data = np.load(data_dir + f"{i+1:04}_rendered.png_config.npz")

    
    images[i] = data['image_colors']
    oracle_global_coords[i] = data['points_3d_world']
    regions[i,:,:,0] = data['points_region_class']
    local_coords[i] = data['local_scene_coords']
    masks[i,:,:,0] = data['mask']
    
    if i == 0:
        W_inv = data['W_inv']
        M = data['M']
        std = data['std']
# Out:
# 100%|██████████| 370/370 [00:13<00:00, 27.57it/s]

# %% [markdown]
# ## load model

# %%
from utilis.experiment_utilis import combined_loss_weighted
import tensorflow as tf
from tensorflow import keras 

# load model
checkpoint_dir = "/data/cornucopia/jz522/experiments/2021-05-17/FPN_resnet_bs16_LR5e-4_w11_CONTINUED_2021-05-17_06:36:41/model_checkpoint"
model = keras.models.load_model(checkpoint_dir, compile=False)
model.compile(optimizer=keras.optimizers.Adam(1e-4), loss=combined_loss_weighted([1, 1]))

# %% [markdown]
# ## predict local scene coords

# %% [markdown]
# **using stiching**

# %%
# from utilis.utilis import crop #, stich

# start_row = [0,0,0,32,32,32]
# start_col = [0,224,448,0,224,448]

# croped_image = crop(images[0:1], start_row, start_col)
# croped_mask = crop(masks[0:1], start_row, start_col)
# pred_local_coords = model.predict([croped_image, croped_mask])

# %% [markdown]
# **feeding entire 256x512 image**

# %%
pred_local_coords = np.zeros((dataset_size, 256, 512, 144))
for i in tqdm(range(dataset_size)):
    pred_local_coords[i] = np.array(model.predict_on_batch([images[i:i+1], masks[i:i+1]]))
# Out:
#   0%|          | 0/370 [00:00<?, ?it/s]
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_3:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 256, 512, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_2:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 256, 512, 1).
# 100%|██████████| 370/370 [00:40<00:00,  9.22it/s]

# %%
# predict loal scene coords
# pred_local_coords = model.predict([images, masks])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_3:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 256, 512, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_2:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 256, 512, 1).

# %% [markdown]
# # unwhiten local scene coords -> get world scene coords

# %%
# 1. convert regions to their mean centers
pred_local_coords_flat = np.reshape(pred_local_coords[:,:,:,:3], (-1,3))
pred_regions = np.argmax(pred_local_coords[:,:,:,3:], axis=-1)
pred_regions_flat = np.reshape(pred_regions, (-1)).astype(int)
pred_global_coords = np.zeros((dataset_size*256*512,3))

# 2. unwhitten local coordinates
for region in tqdm(np.unique(pred_regions_flat)):
    region_coords = pred_local_coords_flat[pred_regions_flat == region]
    unwhite_loc_coords = np.dot(region_coords * std[region] , W_inv[region]) + M[region]

    pred_global_coords[pred_regions_flat == region] = unwhite_loc_coords
    
pred_global_coords = np.reshape(pred_global_coords, (dataset_size, 256, 512, 3))
# Out:
# 100%|██████████| 141/141 [00:49<00:00,  2.86it/s]

# %% [markdown]
# ## inspect

# %%
image_ID = 2

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8))
max_ = max(max(pred_global_coords[image_ID].flatten()), max(oracle_global_coords[image_ID].flatten()))
min_ = min(min(pred_global_coords[image_ID].flatten()), min(oracle_global_coords[image_ID].flatten()))

pred_norm = (pred_global_coords[image_ID] - min_) / (max_ - min_)
ax1.imshow(pred_norm)
ax1.set_title('prediction')

gt_norm = (oracle_global_coords[image_ID] - min_) / (max_ - min_)
ax2.imshow(gt_norm)
ax2.set_title('ground truth')
plt.show()

# %% [markdown]
# ## get pixelwise MSE error

# %%
colormap = np.random.randint(0, high=256, size=(141,3), dtype=int)

# %%
def get_color_map(regions, colormap):

    reg_flat = np.reshape(regions, (-1)).astype(int)
    colored_regions_flat = colormap[reg_flat]
    colored_regions = np.reshape(colored_regions_flat, (256,512,3))
    return colored_regions

# %%
# from utilis.utilis import get_color_map

def visualise_error(image_ID):
    pixelwise_MSE = np.mean(np.square((pred_global_coords[image_ID]*masks[image_ID]) - (oracle_global_coords[image_ID]*masks[image_ID])), axis=-1)
    pixelwise_local_MSE = np.mean(np.square((pred_local_coords[image_ID,:,:,:3]*masks[image_ID]) - (local_coords[image_ID,:,:,:3]*masks[image_ID])), axis=-1)
    
    # IMAGE AND MASK
    fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(18,15))
    
    ax1.imshow(images[image_ID])
    ax1.set_title(f'Image ID: {image_ID+1:04}')
    
    ax2.imshow(masks[image_ID])
    ax2.set_title('GT mask')
      
    colored_regions = get_color_map(regions[image_ID], colormap)
    pred_colored_regions = get_color_map(pred_regions[image_ID], colormap)
    ax3.imshow(pred_colored_regions)
    ax3.set_title('Pred regions')
    
    ax4.imshow(np.abs(pred_colored_regions - colored_regions))
    ax4.set_title('Region Pred. Error')
    
    pixelwise_local_MSE_cap_1 = np.where(pixelwise_local_MSE < 1, pixelwise_local_MSE, 1)
    im5 = ax5.imshow(pixelwise_local_MSE_cap_1)
    ax5.set_title("Local -capped at MSE = 1")
    divider = make_axes_locatable(ax5)
    cax = divider.append_axes('right', size='5%', pad=0.1)
    cbar = fig.colorbar(im5, cax=cax)    

    pixelwise_MSE_cap_1 = np.where(pixelwise_MSE < 1, pixelwise_MSE, 1)
    im6 = ax6.imshow(pixelwise_MSE_cap_1)
    ax6.set_title("Global - capped at MSE = 1")
    divider = make_axes_locatable(ax6)
    cax = divider.append_axes('right', size='5%', pad=0.1)
    cbar = fig.colorbar(im6, cax=cax)

    return fig

# %%
fig = visualise_error(10)
plt.show()

# %%
fig = visualise_error(9)
plt.show()

# %% [markdown]
# # would be useful to colorcode magnitudes of errors. It's informative that MSE > 1 but it would be more informative to know by how much.

# %% [markdown]
# ## save train and validation error maps

# %%
# load json with data split
data_partition_path = "/data/cornucopia/jz522/experiments/2021-05-17/FPN_resnet_bs16_LR5e-4_w11_CONTINUED_2021-05-17_06:36:41/data_partition.json"

data_partition_file = open(data_partition_path)
data_partition = json.load(data_partition_file)
data_partition_file.close()

# %%
# train
train_indexes = np.zeros(len(data_partition['train']), dtype=int)
for ind, image_name in enumerate(data_partition['train']):
    train_indexes[ind] = int(image_name.split('/')[-1].split("_")[0])
    
# val
val_indexes = np.empty(len(data_partition['validation']), dtype=int)
for ind, image_name in enumerate(data_partition['validation']):
    val_indexes[ind] = int(image_name.split('/')[-1].split("_")[0])

# %%
save_dir = "/data/cornucopia/jz522/experiments/model_visualisation/reg_clas_model__17_05_2021/"

for ind in tqdm(train_indexes):
    fig = visualise_error(ind-1)
    fig.savefig(save_dir + "train/" f"{ind:04}", facecolor='w')
    plt.close(fig)
    
for ind in tqdm(val_indexes):
    fig = visualise_error(ind-1)
    fig.savefig(save_dir + "val/" f"{ind:04}", facecolor='w')
    plt.close(fig)
# Out:
# 100%|██████████| 333/333 [06:40<00:00,  1.20s/it]
# 100%|██████████| 37/37 [00:45<00:00,  1.22s/it]

# %% [markdown]
# ## get PLY file with all points

# %%
colors = np.array([[255, 0 , 0], [255, 110, 0], [255, 170, 20], [225,225,0], [255,255,0], [140,255,0], [100,205,10]])
colors = np.reshape(colors, (1, colors.shape[0], 3))
plt.imshow(colors)
plt.show()

colors = np.reshape(colors, (-1,3))
e = [10,3,1,0.5,0.2,0.05,0.01]

# %%
all_images_MSE = np.mean(np.square((pred_global_coords*masks) - (oracle_global_coords*masks)), axis=-1)

vertices = np.reshape(oracle_global_coords, (-1,3))
MSE_values = np.reshape(all_images_MSE, (-1))

# %%
vertices_colors = [colors[0] if i > e[0] else 
                   colors[1] if i > e[1] else
                   colors[2] if i > e[2] else
                   colors[3] if i > e[3] else
                   colors[4] if i > e[4] else
                   colors[5] if i > e[5] else
                   colors[6] for i in tqdm(MSE_values)]
# Out:
#   0%|          | 0/48496640 [00:00<?, ?it/s]
#
#   0%|          | 51032/48496640 [00:00<01:35, 504812.95it/s]
#
#   0%|          | 107654/48496640 [00:00<01:29, 540759.17it/s]
#
#   0%|          | 165167/48496640 [00:00<01:26, 556405.15it/s]
#
#   0%|          | 223651/48496640 [00:00<01:25, 567606.88it/s]
#
#   1%|          | 280421/48496640 [00:00<01:25, 565394.57it/s]
#
#   1%|          | 336968/48496640 [00:00<01:25, 562154.51it/s]
#
#   1%|          | 393191/48496640 [00:00<01:25, 562149.16it/s]
#
#   1%|          | 449411/48496640 [00:00<01:25, 558865.59it/s]
#
#   1%|          | 505555/48496640 [00:00<01:25, 559659.60it/s]
#
#   1%|          | 561636/48496640 [00:01<01:25, 560007.06it/s]
#
#   1%|▏         | 618435/48496640 [00:01<01:25, 562426.30it/s]
#
#   1%|▏         | 674681/48496640 [00:01<01:25, 559206.47it/s]
#
#   2%|▏         | 730608/48496640 [00:01<01:25, 557236.80it/s]
#
#   2%|▏         | 786481/48496640 [00:01<01:25, 557676.70it/s]
#
#   2%|▏         | 842253/48496640 [00:01<01:25, 556456.92it/s]
#
#   2%|▏         | 897902/48496640 [00:01<01:26, 551352.92it/s]
#
#   2%|▏         | 953521/48496640 [00:01<01:26, 552784.81it/s]
#
#   2%|▏         | 1008808/48496640 [00:01<01:26, 551576.88it/s]
#
#   2%|▏         | 1064157/48496640 [00:01<01:25, 552140.52it/s]
#
#   2%|▏         | 1119376/48496640 [00:02<01:26, 548077.82it/s]
#
#   2%|▏         | 1174705/48496640 [00:02<01:26, 549622.11it/s]
#
#   3%|▎         | 1229675/48496640 [00:02<01:26, 549455.94it/s]
#
#   3%|▎         | 1285567/48496640 [00:02<01:25, 552279.47it/s]
#
#   3%|▎         | 1340800/48496640 [00:02<01:25, 551904.27it/s]
#
#   3%|▎         | 1395994/48496640 [00:02<01:25, 550117.49it/s]
#
#   3%|▎         | 1452851/48496640 [00:02<01:24, 555624.79it/s]
#
#   3%|▎         | 1508581/48496640 [00:02<01:24, 556122.52it/s]
#
#   3%|▎         | 1564774/48496640 [00:02<01:24, 557855.49it/s]
#
#   3%|▎         | 1620563/48496640 [00:02<01:24, 555335.75it/s]
#
#   3%|▎         | 1678063/48496640 [00:03<01:23, 561205.07it/s]
#
#   4%|▎         | 1735652/48496640 [00:03<01:22, 565592.60it/s]
#
#   4%|▎         | 1792217/48496640 [00:03<01:24, 555985.40it/s]
#
#   4%|▍         | 1848025/48496640 [00:03<01:23, 556597.27it/s]
#
#   4%|▍         | 1903724/48496640 [00:03<01:23, 556710.58it/s]
#
#   4%|▍         | 1959415/48496640 [00:03<01:23, 555264.66it/s]
#
#   4%|▍         | 2014956/48496640 [00:03<01:23, 554729.48it/s]
#
#   4%|▍         | 2070763/48496640 [00:03<01:23, 555713.42it/s]
#
#   4%|▍         | 2126342/48496640 [00:03<01:24, 546151.04it/s]
#
#   5%|▍         | 2182923/48496640 [00:03<01:23, 551958.07it/s]
#
#   5%|▍         | 2238155/48496640 [00:04<01:24, 547388.22it/s]
#
#   5%|▍         | 2292924/48496640 [00:04<01:26, 535480.83it/s]
#
#   5%|▍         | 2349665/48496640 [00:04<01:24, 544818.06it/s]
#
#   5%|▍         | 2405650/48496640 [00:04<01:23, 549245.18it/s]
#
#   5%|▌         | 2462196/48496640 [00:04<01:23, 554045.96it/s]
#
#   5%|▌         | 2517646/48496640 [00:04<01:23, 551722.29it/s]
#
#   5%|▌         | 2572851/48496640 [00:04<01:23, 547186.01it/s]
#
#   5%|▌         | 2628051/48496640 [00:04<01:23, 548609.13it/s]
#
#   6%|▌         | 2685617/48496640 [00:04<01:22, 556650.93it/s]
#
#   6%|▌         | 2741304/48496640 [00:04<01:22, 554644.72it/s]
#
#   6%|▌         | 2796785/48496640 [00:05<01:24, 540172.48it/s]
#
#   6%|▌         | 2850888/48496640 [00:05<01:24, 537536.34it/s]
#
#   6%|▌         | 2907282/48496640 [00:05<01:23, 545292.01it/s]
#
#   6%|▌         | 2962517/48496640 [00:05<01:23, 547369.56it/s]
#
#   6%|▌         | 3017297/48496640 [00:05<01:23, 545674.87it/s]
#
#   6%|▋         | 3072132/48496640 [00:05<01:23, 546462.34it/s]
#
#   6%|▋         | 3129893/48496640 [00:05<01:21, 555740.86it/s]
#
#   7%|▋         | 3185488/48496640 [00:05<01:21, 554688.22it/s]
#
#   7%|▋         | 3241157/48496640 [00:05<01:21, 555277.83it/s]
#
#   7%|▋         | 3297012/48496640 [00:05<01:21, 556252.48it/s]
#
#   7%|▋         | 3353041/48496640 [00:06<01:20, 557455.16it/s]
#
#   7%|▋         | 3409192/48496640 [00:06<01:20, 558664.63it/s]
#
#   7%|▋         | 3465063/48496640 [00:06<01:21, 555022.74it/s]
#
#   7%|▋         | 3522115/48496640 [00:06<01:20, 559631.94it/s]
#
#   7%|▋         | 3578087/48496640 [00:06<01:23, 540173.36it/s]
#
#   7%|▋         | 3635822/48496640 [00:06<01:21, 551018.41it/s]
#
#   8%|▊         | 3693421/48496640 [00:06<01:20, 558362.81it/s]
#
#   8%|▊         | 3749365/48496640 [00:06<01:20, 553502.88it/s]
#
#   8%|▊         | 3804824/48496640 [00:06<01:20, 553818.50it/s]
#
#   8%|▊         | 3860262/48496640 [00:06<01:21, 550197.30it/s]
#
#   8%|▊         | 3915323/48496640 [00:07<01:21, 547966.16it/s]
#
#   8%|▊         | 3970148/48496640 [00:07<01:21, 547033.66it/s]
#
#   8%|▊         | 4024871/48496640 [00:07<01:21, 545607.27it/s]
#
#   8%|▊         | 4079445/48496640 [00:07<01:21, 544159.10it/s]
#
#   9%|▊         | 4134723/48496640 [00:07<01:21, 546721.77it/s]
#
#   9%|▊         | 4191752/48496640 [00:07<01:20, 553744.48it/s]
#
#   9%|▉         | 4247137/48496640 [00:07<01:20, 552699.23it/s]
#
#   9%|▉         | 4304958/48496640 [00:07<01:18, 560314.29it/s]
#
#   9%|▉         | 4363407/48496640 [00:07<01:17, 567542.10it/s]
#
#   9%|▉         | 4420169/48496640 [00:07<01:17, 565941.63it/s]
#
#   9%|▉         | 4476770/48496640 [00:08<01:18, 562273.75it/s]
#
#   9%|▉         | 4533006/48496640 [00:08<01:18, 560126.19it/s]
#
#   9%|▉         | 4589026/48496640 [00:08<01:18, 557058.94it/s]
#
#  10%|▉         | 4644739/48496640 [00:08<01:19, 552534.80it/s]
#
#  10%|▉         | 4701321/48496640 [00:08<01:18, 556465.42it/s]
#
#  10%|▉         | 4756979/48496640 [00:08<01:18, 555935.11it/s]
#
#  10%|▉         | 4812949/48496640 [00:08<01:18, 557052.41it/s]
#
#  10%|█         | 4868912/48496640 [00:08<01:18, 557618.17it/s]
#
#  10%|█         | 4924969/48496640 [00:08<01:18, 558486.00it/s]
#
#  10%|█         | 4980821/48496640 [00:09<01:19, 549796.05it/s]
#
#  10%|█         | 5037601/48496640 [00:09<01:18, 555123.30it/s]
#
#  11%|█         | 5095200/48496640 [00:09<01:17, 561324.37it/s]
#
#  11%|█         | 5151358/48496640 [00:09<01:17, 559638.60it/s]
#
#  11%|█         | 5210103/48496640 [00:09<01:16, 567921.93it/s]
#
#  11%|█         | 5266914/48496640 [00:09<01:16, 562206.11it/s]
#
#  11%|█         | 5323158/48496640 [00:09<01:17, 555135.08it/s]
#
#  11%|█         | 5378702/48496640 [00:09<01:17, 552869.92it/s]
#
#  11%|█         | 5434009/48496640 [00:09<01:18, 546550.21it/s]
#
#  11%|█▏        | 5489472/48496640 [00:09<01:18, 548925.74it/s]
#
#  11%|█▏        | 5544385/48496640 [00:10<01:19, 539700.21it/s]
#
#  12%|█▏        | 5600197/48496640 [00:10<01:18, 545107.88it/s]
#
#  12%|█▏        | 5657113/48496640 [00:10<01:17, 552212.82it/s]
#
#  12%|█▏        | 5714224/48496640 [00:10<01:16, 557818.13it/s]
#
#  12%|█▏        | 5770038/48496640 [00:10<01:17, 549414.92it/s]
#
#  12%|█▏        | 5825353/48496640 [00:10<01:17, 550513.28it/s]
#
#  12%|█▏        | 5882377/48496640 [00:10<01:16, 556363.04it/s]
#
#  12%|█▏        | 5938044/48496640 [00:10<01:18, 543631.96it/s]
#
#  12%|█▏        | 5994401/48496640 [00:10<01:17, 549480.12it/s]
#
#  12%|█▏        | 6049417/48496640 [00:10<01:17, 549246.30it/s]
#
#  13%|█▎        | 6104389/48496640 [00:11<01:17, 549052.26it/s]
#
#  13%|█▎        | 6159327/48496640 [00:11<01:18, 541878.88it/s]
#
#  13%|█▎        | 6213844/48496640 [00:11<01:17, 542845.69it/s]
#
#  13%|█▎        | 6268237/48496640 [00:11<01:17, 543164.98it/s]
#
#  13%|█▎        | 6322574/48496640 [00:11<01:17, 541922.77it/s]
#
#  13%|█▎        | 6376781/48496640 [00:11<01:18, 537076.50it/s]
#
#  13%|█▎        | 6430506/48496640 [00:11<01:18, 534778.18it/s]
#
#  13%|█▎        | 6486939/48496640 [00:11<01:17, 543543.02it/s]
#  13%|█▎        | 6541878/48496640 [00:11<01:16, 545279.96it/s]
#
#  14%|█▎        | 6596420/48496640 [00:11<01:17, 539041.29it/s]
#
#  14%|█▎        | 6653366/48496640 [00:12<01:16, 548053.55it/s]
#
#  14%|█▍        | 6708199/48496640 [00:12<01:16, 544350.17it/s]
#
#  14%|█▍        | 6762857/48496640 [00:12<01:16, 545009.05it/s]
#
#  14%|█▍        | 6817374/48496640 [00:12<01:17, 536421.30it/s]
#
#  14%|█▍        | 6874053/48496640 [00:12<01:16, 545378.71it/s]
#
#  14%|█▍        | 6930411/48496640 [00:12<01:15, 550772.45it/s]
#
#  14%|█▍        | 6985523/48496640 [00:12<01:17, 532420.72it/s]
#
#  15%|█▍        | 7041155/48496640 [00:12<01:16, 539377.26it/s]
#
#  15%|█▍        | 7097364/48496640 [00:12<01:15, 546045.67it/s]
#
#  15%|█▍        | 7152069/48496640 [00:12<01:16, 539058.08it/s]
#
#  15%|█▍        | 7206528/48496640 [00:13<01:16, 540679.27it/s]
#
#  15%|█▍        | 7263978/48496640 [00:13<01:14, 550682.29it/s]
#
#  15%|█▌        | 7319103/48496640 [00:13<01:16, 540238.33it/s]
#
#  15%|█▌        | 7374570/48496640 [00:13<01:15, 544474.30it/s]
#
#  15%|█▌        | 7429613/48496640 [00:13<01:15, 546231.35it/s]
#
#  15%|█▌        | 7484468/48496640 [00:13<01:14, 546917.00it/s]
#
#  16%|█▌        | 7539193/48496640 [00:13<01:15, 540158.40it/s]
#
#  16%|█▌        | 7596042/48496640 [00:13<01:14, 548535.40it/s]
#
#  16%|█▌        | 7651738/48496640 [00:13<01:14, 551034.20it/s]
#
#  16%|█▌        | 7706871/48496640 [00:13<01:15, 543429.66it/s]
#
#  16%|█▌        | 7761970/48496640 [00:14<01:14, 545657.22it/s]
#
#  16%|█▌        | 7818926/48496640 [00:14<01:13, 552737.96it/s]
#
#  16%|█▌        | 7875728/48496640 [00:14<01:12, 557277.01it/s]
#
#  16%|█▋        | 7931480/48496640 [00:14<01:13, 549969.19it/s]
#
#  16%|█▋        | 7988981/48496640 [00:14<01:12, 557380.77it/s]
#
#  17%|█▋        | 8044754/48496640 [00:14<01:12, 555073.00it/s]
#
#  17%|█▋        | 8100286/48496640 [00:14<01:13, 547501.85it/s]
#
#  17%|█▋        | 8155070/48496640 [00:14<01:14, 543948.41it/s]
#
#  17%|█▋        | 8209997/48496640 [00:14<01:13, 545515.96it/s]
#
#  17%|█▋        | 8264568/48496640 [00:15<01:14, 543378.75it/s]
#
#  17%|█▋        | 8318919/48496640 [00:15<01:15, 532622.79it/s]
#
#  17%|█▋        | 8375918/48496640 [00:15<01:13, 543587.86it/s]
#
#  17%|█▋        | 8432282/48496640 [00:15<01:12, 549507.21it/s]
#
#  18%|█▊        | 8487282/48496640 [00:15<01:14, 536283.98it/s]
#
#  18%|█▊        | 8541003/48496640 [00:15<01:14, 536317.13it/s]
#
#  18%|█▊        | 8597396/48496640 [00:15<01:13, 544451.34it/s]
#
#  18%|█▊        | 8652053/48496640 [00:15<01:13, 545073.81it/s]
#
#  18%|█▊        | 8706604/48496640 [00:15<01:14, 534264.63it/s]
#
#  18%|█▊        | 8762860/48496640 [00:15<01:13, 542577.34it/s]
#
#  18%|█▊        | 8817460/48496640 [00:16<01:12, 543585.08it/s]
#
#  18%|█▊        | 8871867/48496640 [00:16<01:13, 535915.03it/s]
#
#  18%|█▊        | 8925510/48496640 [00:16<01:13, 535940.05it/s]
#
#  19%|█▊        | 8981588/48496640 [00:16<01:12, 543296.36it/s]
#
#  19%|█▊        | 9037953/48496640 [00:16<01:11, 549347.16it/s]
#
#  19%|█▊        | 9092917/48496640 [00:16<01:13, 536496.40it/s]
#
#  19%|█▉        | 9146831/48496640 [00:16<01:13, 537269.39it/s]
#
#  19%|█▉        | 9200846/48496640 [00:16<01:13, 538118.41it/s]
#
#  19%|█▉        | 9254887/48496640 [00:16<01:12, 538786.76it/s]
#
#  19%|█▉        | 9308796/48496640 [00:16<01:13, 536793.41it/s]
#
#  19%|█▉        | 9362497/48496640 [00:17<01:13, 534921.93it/s]
#
#  19%|█▉        | 9417126/48496640 [00:17<01:12, 538299.94it/s]
#
#  20%|█▉        | 9470970/48496640 [00:17<01:13, 533970.18it/s]
#
#  20%|█▉        | 9524383/48496640 [00:17<01:13, 533782.25it/s]
#
#  20%|█▉        | 9577772/48496640 [00:17<01:12, 533671.99it/s]
#
#  20%|█▉        | 9631147/48496640 [00:17<01:12, 533663.15it/s]
#
#  20%|█▉        | 9684519/48496640 [00:17<01:13, 527774.86it/s]
#
#  20%|██        | 9738662/48496640 [00:17<01:12, 531824.03it/s]
#
#  20%|██        | 9791989/48496640 [00:17<01:12, 532249.91it/s]
#
#  20%|██        | 9845226/48496640 [00:17<01:13, 528149.43it/s]
#
#  20%|██        | 9898783/48496640 [00:18<01:12, 530350.43it/s]
#
#  21%|██        | 9952833/48496640 [00:18<01:12, 533372.76it/s]
#
#  21%|██        | 10006490/48496640 [00:18<01:12, 534324.02it/s]
#
#  21%|██        | 10059930/48496640 [00:18<01:13, 524922.46it/s]
#
#  21%|██        | 10115506/48496640 [00:18<01:11, 534034.83it/s]
#
#  21%|██        | 10171936/48496640 [00:18<01:10, 543016.02it/s]
#
#  21%|██        | 10226276/48496640 [00:18<01:11, 538300.84it/s]
#
#  21%|██        | 10280288/48496640 [00:18<01:10, 538835.63it/s]
#
#  21%|██▏       | 10336146/48496640 [00:18<01:10, 544708.65it/s]
#
#  21%|██▏       | 10390639/48496640 [00:18<01:10, 542565.11it/s]
#
#  22%|██▏       | 10444912/48496640 [00:19<01:10, 540067.13it/s]
#
#  22%|██▏       | 10499476/48496640 [00:19<01:10, 541721.14it/s]
#
#  22%|██▏       | 10553658/48496640 [00:19<01:10, 540535.55it/s]
#
#  22%|██▏       | 10607719/48496640 [00:19<01:10, 534683.00it/s]
#
#  22%|██▏       | 10661757/48496640 [00:19<01:10, 536317.27it/s]
#
#  22%|██▏       | 10716556/48496640 [00:19<01:09, 539785.77it/s]
#
#  22%|██▏       | 10772794/48496640 [00:19<01:09, 546519.63it/s]
#
#  22%|██▏       | 10827876/48496640 [00:19<01:08, 547800.03it/s]
#
#  22%|██▏       | 10882666/48496640 [00:19<01:09, 537963.34it/s]
#
#  23%|██▎       | 10938400/48496640 [00:19<01:09, 543685.28it/s]
#
#  23%|██▎       | 10992816/48496640 [00:20<01:08, 543822.53it/s]
#
#  23%|██▎       | 11047226/48496640 [00:20<01:09, 539426.86it/s]
#
#  23%|██▎       | 11101992/48496640 [00:20<01:09, 541865.21it/s]
#
#  23%|██▎       | 11157289/48496640 [00:20<01:08, 545162.52it/s]
#
#  23%|██▎       | 11211822/48496640 [00:20<01:08, 541276.77it/s]
#
#  23%|██▎       | 11265966/48496640 [00:20<01:11, 524203.75it/s]
#
#  23%|██▎       | 11319137/48496640 [00:20<01:10, 526388.04it/s]
#
#  23%|██▎       | 11375889/48496640 [00:20<01:08, 538474.93it/s]
#
#  24%|██▎       | 11431887/48496640 [00:20<01:08, 544831.43it/s]
#
#  24%|██▎       | 11486835/48496640 [00:20<01:07, 546208.01it/s]
#
#  24%|██▍       | 11541506/48496640 [00:21<01:08, 538876.71it/s]
#
#  24%|██▍       | 11596838/48496640 [00:21<01:07, 543141.64it/s]
#
#  24%|██▍       | 11651196/48496640 [00:21<01:08, 541483.65it/s]
#
#  24%|██▍       | 11705375/48496640 [00:21<01:08, 533289.41it/s]
#
#  24%|██▍       | 11759443/48496640 [00:21<01:08, 535463.36it/s]
#
#  24%|██▍       | 11813162/48496640 [00:21<01:08, 535972.52it/s]
#
#  24%|██▍       | 11867632/48496640 [00:21<01:08, 538563.85it/s]
#
#  25%|██▍       | 11921508/48496640 [00:21<01:08, 534106.88it/s]
#
#  25%|██▍       | 11975422/48496640 [00:21<01:08, 535596.79it/s]
#
#  25%|██▍       | 12028997/48496640 [00:22<01:08, 531882.26it/s]
#
#  25%|██▍       | 12082973/48496640 [00:22<01:08, 534218.58it/s]
#
#  25%|██▌       | 12138718/48496640 [00:22<01:07, 541136.28it/s]
#
#  25%|██▌       | 12193003/48496640 [00:22<01:07, 541558.61it/s]
#
#  25%|██▌       | 12247192/48496640 [00:22<01:06, 541654.36it/s]
#
#  25%|██▌       | 12301365/48496640 [00:22<01:06, 540684.57it/s]
#
#  25%|██▌       | 12355439/48496640 [00:22<01:08, 525544.00it/s]
#
#  26%|██▌       | 12408086/48496640 [00:22<01:09, 522357.31it/s]
#
#  26%|██▌       | 12462368/48496640 [00:22<01:08, 528367.99it/s]
#
#  26%|██▌       | 12516129/48496640 [00:22<01:07, 531092.71it/s]
#
#  26%|██▌       | 12569282/48496640 [00:23<01:07, 530336.41it/s]
#
#  26%|██▌       | 12623853/48496640 [00:23<01:07, 534905.10it/s]
#
#  26%|██▌       | 12677429/48496640 [00:23<01:06, 535154.93it/s]
#
#  26%|██▋       | 12735557/48496640 [00:23<01:05, 548933.61it/s]
#
#  26%|██▋       | 12790469/48496640 [00:23<01:05, 543734.64it/s]
#
#  26%|██▋       | 12846563/48496640 [00:23<01:04, 548846.52it/s]
#  27%|██▋       | 12901468/48496640 [00:23<01:05, 546928.71it/s]
#
#  27%|██▋       | 12956176/48496640 [00:23<01:05, 546574.79it/s]
#
#  27%|██▋       | 13010844/48496640 [00:23<01:05, 542590.72it/s]
#
#  27%|██▋       | 13065115/48496640 [00:23<01:05, 541742.62it/s]
#
#  27%|██▋       | 13119298/48496640 [00:24<01:05, 541333.33it/s]
#
#  27%|██▋       | 13173437/48496640 [00:24<01:05, 539654.82it/s]
#
#  27%|██▋       | 13227407/48496640 [00:24<01:05, 537732.81it/s]
#
#  27%|██▋       | 13281184/48496640 [00:24<01:06, 532889.63it/s]
#
#  27%|██▋       | 13335537/48496640 [00:24<01:05, 536041.46it/s]
#
#  28%|██▊       | 13389152/48496640 [00:24<01:05, 536009.25it/s]
#
#  28%|██▊       | 13445132/48496640 [00:24<01:04, 543103.78it/s]
#
#  28%|██▊       | 13501176/48496640 [00:24<01:03, 548277.44it/s]
#
#  28%|██▊       | 13556348/48496640 [00:24<01:03, 549302.43it/s]
#
#  28%|██▊       | 13611349/48496640 [00:24<01:03, 549508.96it/s]
#
#  28%|██▊       | 13666858/48496640 [00:25<01:03, 551177.21it/s]
#
#  28%|██▊       | 13721979/48496640 [00:25<01:03, 547254.77it/s]
#
#  28%|██▊       | 13776713/48496640 [00:25<01:03, 547086.98it/s]
#
#  29%|██▊       | 13831428/48496640 [00:25<01:04, 538981.12it/s]
#
#  29%|██▊       | 13885935/48496640 [00:25<01:04, 540778.91it/s]
#
#  29%|██▊       | 13940875/48496640 [00:25<01:03, 543335.66it/s]
#
#  29%|██▉       | 13995227/48496640 [00:25<01:03, 539564.67it/s]
#
#  29%|██▉       | 14051337/48496640 [00:25<01:03, 545957.83it/s]
#
#  29%|██▉       | 14105951/48496640 [00:25<01:03, 545077.83it/s]
#
#  29%|██▉       | 14160471/48496640 [00:25<01:04, 534658.20it/s]
#
#  29%|██▉       | 14216738/48496640 [00:26<01:03, 542909.27it/s]
#
#  29%|██▉       | 14272234/48496640 [00:26<01:02, 546476.72it/s]
#
#  30%|██▉       | 14328869/48496640 [00:26<01:01, 552381.40it/s]
#
#  30%|██▉       | 14384139/48496640 [00:26<01:02, 542887.85it/s]
#
#  30%|██▉       | 14438492/48496640 [00:26<01:02, 543073.27it/s]
#
#  30%|██▉       | 14493486/48496640 [00:26<01:02, 545105.70it/s]
#
#  30%|██▉       | 14548026/48496640 [00:26<01:03, 537715.11it/s]
#
#  30%|███       | 14602268/48496640 [00:26<01:02, 539100.91it/s]
#
#  30%|███       | 14659393/48496640 [00:26<01:01, 548635.95it/s]
#
#  30%|███       | 14715769/48496640 [00:26<01:01, 553134.61it/s]
#
#  30%|███       | 14771108/48496640 [00:27<01:02, 540959.96it/s]
#
#  31%|███       | 14826211/48496640 [00:27<01:01, 543918.99it/s]
#
#  31%|███       | 14881328/48496640 [00:27<01:01, 546058.71it/s]
#
#  31%|███       | 14937486/48496640 [00:27<01:00, 550665.65it/s]
#
#  31%|███       | 14992587/48496640 [00:27<01:01, 544142.34it/s]
#
#  31%|███       | 15047579/48496640 [00:27<01:01, 545849.16it/s]
#
#  31%|███       | 15104889/48496640 [00:27<01:00, 553944.70it/s]
#
#  31%|███▏      | 15161746/48496640 [00:27<00:59, 558301.19it/s]
#
#  31%|███▏      | 15217599/48496640 [00:27<01:00, 546531.60it/s]
#
#  31%|███▏      | 15272319/48496640 [00:27<01:01, 542769.21it/s]
#
#  32%|███▏      | 15327823/48496640 [00:28<01:00, 546381.30it/s]
#
#  32%|███▏      | 15382500/48496640 [00:28<01:00, 543741.84it/s]
#
#  32%|███▏      | 15437705/48496640 [00:28<01:00, 546196.81it/s]
#
#  32%|███▏      | 15493940/48496640 [00:28<00:59, 550994.71it/s]
#
#  32%|███▏      | 15549059/48496640 [00:28<00:59, 549442.65it/s]
#
#  32%|███▏      | 15604018/48496640 [00:28<00:59, 548473.97it/s]
#
#  32%|███▏      | 15660784/48496640 [00:28<00:59, 554191.54it/s]
#
#  32%|███▏      | 15716214/48496640 [00:28<00:59, 554037.02it/s]
#
#  33%|███▎      | 15772517/48496640 [00:28<00:58, 556723.28it/s]
#
#  33%|███▎      | 15828195/48496640 [00:28<00:59, 552870.99it/s]
#
#  33%|███▎      | 15885120/48496640 [00:29<00:58, 557745.62it/s]
#
#  33%|███▎      | 15940905/48496640 [00:29<00:58, 557048.31it/s]
#
#  33%|███▎      | 15996617/48496640 [00:29<00:58, 552578.92it/s]
#
#  33%|███▎      | 16051887/48496640 [00:29<00:58, 551795.65it/s]
#
#  33%|███▎      | 16109445/48496640 [00:29<00:57, 558876.08it/s]
#
#  33%|███▎      | 16165343/48496640 [00:29<01:01, 528567.47it/s]
#
#  33%|███▎      | 16222362/48496640 [00:29<00:59, 540526.34it/s]
#
#  34%|███▎      | 16277558/48496640 [00:29<00:59, 543848.80it/s]
#
#  34%|███▎      | 16332155/48496640 [00:29<00:59, 544097.04it/s]
#
#  34%|███▍      | 16387640/48496640 [00:30<00:58, 547268.73it/s]
#
#  34%|███▍      | 16442476/48496640 [00:30<00:58, 547561.36it/s]
#
#  34%|███▍      | 16497309/48496640 [00:30<00:59, 539341.17it/s]
#
#  34%|███▍      | 16551767/48496640 [00:30<00:59, 540829.37it/s]
#
#  34%|███▍      | 16606472/48496640 [00:30<00:58, 542670.16it/s]
#
#  34%|███▍      | 16662718/48496640 [00:30<00:58, 548553.73it/s]
#
#  34%|███▍      | 16717608/48496640 [00:30<00:58, 546022.29it/s]
#
#  35%|███▍      | 16772246/48496640 [00:30<00:58, 546123.93it/s]
#
#  35%|███▍      | 16828868/48496640 [00:30<00:57, 552117.60it/s]
#
#  35%|███▍      | 16884096/48496640 [00:30<00:57, 547876.34it/s]
#
#  35%|███▍      | 16938975/48496640 [00:31<00:57, 548143.74it/s]
#
#  35%|███▌      | 16994125/48496640 [00:31<00:57, 549140.45it/s]
#
#  35%|███▌      | 17049807/48496640 [00:31<00:57, 551430.70it/s]
#
#  35%|███▌      | 17104958/48496640 [00:31<00:57, 542225.73it/s]
#
#  35%|███▌      | 17161552/48496640 [00:31<00:57, 549238.47it/s]
#
#  36%|███▌      | 17216729/48496640 [00:31<00:56, 549986.10it/s]
#
#  36%|███▌      | 17271754/48496640 [00:31<00:56, 547938.34it/s]
#
#  36%|███▌      | 17326567/48496640 [00:31<00:57, 544565.24it/s]
#
#  36%|███▌      | 17383263/48496640 [00:31<00:56, 551216.19it/s]
#
#  36%|███▌      | 17438402/48496640 [00:31<00:56, 551084.91it/s]
#
#  36%|███▌      | 17493523/48496640 [00:32<00:57, 543146.50it/s]
#
#  36%|███▌      | 17548183/48496640 [00:32<00:56, 544158.21it/s]
#
#  36%|███▋      | 17602622/48496640 [00:32<00:56, 543898.58it/s]
#
#  36%|███▋      | 17657028/48496640 [00:32<00:57, 538054.95it/s]
#
#  37%|███▋      | 17710855/48496640 [00:32<00:57, 537169.62it/s]
#
#  37%|███▋      | 17764587/48496640 [00:32<00:57, 536359.58it/s]
#
#  37%|███▋      | 17819522/48496640 [00:32<00:56, 540221.49it/s]
#
#  37%|███▋      | 17873554/48496640 [00:32<00:57, 535931.75it/s]
#
#  37%|███▋      | 17930223/48496640 [00:32<00:56, 545064.73it/s]
#
#  37%|███▋      | 17987031/48496640 [00:32<00:55, 551918.03it/s]
#
#  37%|███▋      | 18042240/48496640 [00:33<00:56, 542633.60it/s]
#
#  37%|███▋      | 18096547/48496640 [00:33<00:56, 540509.56it/s]
#
#  37%|███▋      | 18153572/48496640 [00:33<00:55, 549307.14it/s]
#
#  38%|███▊      | 18210469/48496640 [00:33<00:54, 555143.90it/s]
#
#  38%|███▊      | 18266012/48496640 [00:33<00:54, 551070.69it/s]
#
#  38%|███▊      | 18322218/48496640 [00:33<00:54, 554330.52it/s]
#
#  38%|███▊      | 18377672/48496640 [00:33<00:54, 551434.88it/s]
#
#  38%|███▊      | 18434562/48496640 [00:33<00:54, 556625.78it/s]
#
#  38%|███▊      | 18490241/48496640 [00:33<00:54, 548866.62it/s]
#
#  38%|███▊      | 18546686/48496640 [00:33<00:54, 553471.25it/s]
#
#  38%|███▊      | 18602062/48496640 [00:34<00:54, 552426.18it/s]
#
#  38%|███▊      | 18657324/48496640 [00:34<00:55, 541351.86it/s]
#
#  39%|███▊      | 18711515/48496640 [00:34<00:55, 541180.77it/s]
#
#  39%|███▊      | 18765753/48496640 [00:34<00:54, 541531.65it/s]
#
#  39%|███▉      | 18820257/48496640 [00:34<00:54, 542569.32it/s]
#
#  39%|███▉      | 18874535/48496640 [00:34<00:55, 535925.80it/s]
#
#  39%|███▉      | 18929218/48496640 [00:34<00:54, 539146.32it/s]
#
#  39%|███▉      | 18983217/48496640 [00:34<00:54, 539392.94it/s]
#
#  39%|███▉      | 19037174/48496640 [00:34<00:54, 536837.99it/s]
#
#  39%|███▉      | 19090991/48496640 [00:34<00:54, 537229.54it/s]
#
#  39%|███▉      | 19144724/48496640 [00:35<00:54, 535873.61it/s]
#
#  40%|███▉      | 19199461/48496640 [00:35<00:54, 539297.67it/s]
#  40%|███▉      | 19254246/48496640 [00:35<00:53, 541849.59it/s]
#
#  40%|███▉      | 19308437/48496640 [00:35<00:54, 539334.45it/s]
#
#  40%|███▉      | 19364962/48496640 [00:35<00:53, 547062.40it/s]
#
#  40%|████      | 19419677/48496640 [00:35<00:53, 544343.17it/s]
#
#  40%|████      | 19474120/48496640 [00:35<00:54, 535082.57it/s]
#
#  40%|████      | 19529114/48496640 [00:35<00:53, 539464.44it/s]
#
#  40%|████      | 19583713/48496640 [00:35<00:53, 541396.80it/s]
#
#  40%|████      | 19638684/48496640 [00:35<00:53, 543866.62it/s]
#
#  41%|████      | 19693091/48496640 [00:36<00:53, 538521.70it/s]
#
#  41%|████      | 19748073/48496640 [00:36<00:53, 541870.49it/s]
#
#  41%|████      | 19805616/48496640 [00:36<00:51, 551857.71it/s]
#
#  41%|████      | 19862808/48496640 [00:36<00:51, 557840.55it/s]
#
#  41%|████      | 19918611/48496640 [00:36<00:52, 546529.87it/s]
#
#  41%|████      | 19973390/48496640 [00:36<00:52, 546895.49it/s]
#
#  41%|████▏     | 20028346/48496640 [00:36<00:51, 547681.96it/s]
#
#  41%|████▏     | 20083612/48496640 [00:36<00:51, 549159.47it/s]
#
#  42%|████▏     | 20138551/48496640 [00:36<00:52, 543099.97it/s]
#
#  42%|████▏     | 20193958/48496640 [00:36<00:51, 546347.54it/s]
#
#  42%|████▏     | 20251492/48496640 [00:37<00:50, 554968.00it/s]
#
#  42%|████▏     | 20307324/48496640 [00:37<00:50, 555961.10it/s]
#
#  42%|████▏     | 20362938/48496640 [00:37<00:50, 554883.93it/s]
#
#  42%|████▏     | 20420799/48496640 [00:37<00:49, 561965.90it/s]
#
#  42%|████▏     | 20477008/48496640 [00:37<00:50, 549889.92it/s]
#
#  42%|████▏     | 20532060/48496640 [00:37<00:50, 549681.36it/s]
#
#  42%|████▏     | 20589477/48496640 [00:37<00:50, 556931.10it/s]
#
#  43%|████▎     | 20645349/48496640 [00:37<00:49, 557458.40it/s]
#
#  43%|████▎     | 20701124/48496640 [00:37<00:49, 556683.31it/s]
#
#  43%|████▎     | 20756812/48496640 [00:38<00:50, 547755.05it/s]
#
#  43%|████▎     | 20812735/48496640 [00:38<00:50, 551142.38it/s]
#
#  43%|████▎     | 20867884/48496640 [00:38<00:50, 551058.93it/s]
#
#  43%|████▎     | 20923212/48496640 [00:38<00:49, 551717.12it/s]
#
#  43%|████▎     | 20978402/48496640 [00:38<00:50, 546942.95it/s]
#
#  43%|████▎     | 21035675/48496640 [00:38<00:49, 554598.07it/s]
#
#  43%|████▎     | 21093573/48496640 [00:38<00:48, 561856.57it/s]
#
#  44%|████▎     | 21149970/48496640 [00:38<00:48, 562482.85it/s]
#
#  44%|████▎     | 21206233/48496640 [00:38<00:49, 556267.78it/s]
#
#  44%|████▍     | 21262047/48496640 [00:38<00:48, 556818.35it/s]
#
#  44%|████▍     | 21318662/48496640 [00:39<00:48, 559594.33it/s]
#
#  44%|████▍     | 21377061/48496640 [00:39<00:47, 566871.05it/s]
#
#  44%|████▍     | 21434671/48496640 [00:39<00:47, 569624.01it/s]
#
#  44%|████▍     | 21493717/48496640 [00:39<00:46, 575753.85it/s]
#
#  44%|████▍     | 21551301/48496640 [00:39<00:47, 571856.44it/s]
#
#  45%|████▍     | 21609882/48496640 [00:39<00:46, 576013.92it/s]
#
#  45%|████▍     | 21667494/48496640 [00:39<00:47, 561793.08it/s]
#
#  45%|████▍     | 21725275/48496640 [00:39<00:47, 566494.67it/s]
#
#  45%|████▍     | 21781991/48496640 [00:39<00:47, 561056.10it/s]
#
#  45%|████▌     | 21838148/48496640 [00:39<00:47, 561016.11it/s]
#
#  45%|████▌     | 21894286/48496640 [00:40<00:47, 554953.59it/s]
#
#  45%|████▌     | 21952113/48496640 [00:40<00:47, 561831.62it/s]
#
#  45%|████▌     | 22008331/48496640 [00:40<00:47, 561062.74it/s]
#
#  45%|████▌     | 22064461/48496640 [00:40<00:47, 560439.52it/s]
#
#  46%|████▌     | 22120521/48496640 [00:40<00:47, 559705.75it/s]
#
#  46%|████▌     | 22176503/48496640 [00:40<00:47, 552946.88it/s]
#
#  46%|████▌     | 22232534/48496640 [00:40<00:47, 555124.25it/s]
#
#  46%|████▌     | 22289383/48496640 [00:40<00:46, 559093.79it/s]
#
#  46%|████▌     | 22346879/48496640 [00:40<00:46, 563819.40it/s]
#
#  46%|████▌     | 22403276/48496640 [00:40<00:46, 558287.30it/s]
#
#  46%|████▋     | 22460060/48496640 [00:41<00:46, 561121.73it/s]
#
#  46%|████▋     | 22516190/48496640 [00:41<00:46, 560894.95it/s]
#
#  47%|████▋     | 22572292/48496640 [00:41<00:47, 549802.90it/s]
#
#  47%|████▋     | 22629975/48496640 [00:41<00:46, 557762.57it/s]
#
#  47%|████▋     | 22686344/48496640 [00:41<00:46, 559514.11it/s]
#
#  47%|████▋     | 22742334/48496640 [00:41<00:46, 557466.24it/s]
#
#  47%|████▋     | 22798108/48496640 [00:41<00:46, 550006.72it/s]
#
#  47%|████▋     | 22855650/48496640 [00:41<00:45, 557506.29it/s]
#
#  47%|████▋     | 22912846/48496640 [00:41<00:45, 561790.37it/s]
#
#  47%|████▋     | 22970068/48496640 [00:41<00:45, 564891.16it/s]
#
#  47%|████▋     | 23026581/48496640 [00:42<00:45, 555738.31it/s]
#
#  48%|████▊     | 23082201/48496640 [00:42<00:45, 553051.15it/s]
#
#  48%|████▊     | 23139587/48496640 [00:42<00:45, 559201.66it/s]
#
#  48%|████▊     | 23195538/48496640 [00:42<00:45, 555098.76it/s]
#
#  48%|████▊     | 23251073/48496640 [00:42<00:46, 541269.00it/s]
#
#  48%|████▊     | 23305959/48496640 [00:42<00:46, 543481.84it/s]
#
#  48%|████▊     | 23361814/48496640 [00:42<00:45, 547915.74it/s]
#
#  48%|████▊     | 23416657/48496640 [00:42<00:46, 541671.97it/s]
#
#  48%|████▊     | 23472458/48496640 [00:42<00:45, 546483.70it/s]
#
#  49%|████▊     | 23529289/48496640 [00:42<00:45, 552946.49it/s]
#
#  49%|████▊     | 23586172/48496640 [00:43<00:44, 557667.32it/s]
#
#  49%|████▊     | 23641968/48496640 [00:43<00:44, 553737.24it/s]
#
#  49%|████▉     | 23697634/48496640 [00:43<00:44, 554602.18it/s]
#
#  49%|████▉     | 23755023/48496640 [00:43<00:44, 560345.47it/s]
#
#  49%|████▉     | 23811074/48496640 [00:43<00:44, 553593.28it/s]
#
#  49%|████▉     | 23868272/48496640 [00:43<00:44, 559040.10it/s]
#
#  49%|████▉     | 23924202/48496640 [00:43<00:44, 551938.94it/s]
#
#  49%|████▉     | 23979429/48496640 [00:43<00:44, 550822.39it/s]
#
#  50%|████▉     | 24034630/48496640 [00:43<00:44, 551055.80it/s]
#
#  50%|████▉     | 24090466/48496640 [00:43<00:44, 553223.84it/s]
#
#  50%|████▉     | 24147946/48496640 [00:44<00:43, 559652.13it/s]
#
#  50%|████▉     | 24203925/48496640 [00:44<00:44, 550817.65it/s]
#
#  50%|█████     | 24260841/48496640 [00:44<00:43, 556238.32it/s]
#
#  50%|█████     | 24316833/48496640 [00:44<00:43, 557326.12it/s]
#
#  50%|█████     | 24373959/48496640 [00:44<00:42, 561473.36it/s]
#
#  50%|█████     | 24430127/48496640 [00:44<00:43, 551946.06it/s]
#
#  50%|█████     | 24486125/48496640 [00:44<00:43, 554314.94it/s]
#
#  51%|█████     | 24543460/48496640 [00:44<00:42, 559959.31it/s]
#
#  51%|█████     | 24599488/48496640 [00:44<00:42, 559264.19it/s]
#
#  51%|█████     | 24655437/48496640 [00:45<00:42, 556834.04it/s]
#
#  51%|█████     | 24713600/48496640 [00:45<00:42, 564211.52it/s]
#
#  51%|█████     | 24770039/48496640 [00:45<00:42, 563084.34it/s]
#
#  51%|█████     | 24826360/48496640 [00:45<00:42, 554333.63it/s]
#
#  51%|█████▏    | 24882503/48496640 [00:45<00:42, 556427.71it/s]
#
#  51%|█████▏    | 24938174/48496640 [00:45<00:42, 555478.67it/s]
#
#  52%|█████▏    | 24993741/48496640 [00:45<00:43, 546497.76it/s]
#
#  52%|█████▏    | 25048430/48496640 [00:45<00:42, 545978.09it/s]
#
#  52%|█████▏    | 25104166/48496640 [00:45<00:42, 549342.89it/s]
#
#  52%|█████▏    | 25160885/48496640 [00:45<00:42, 554644.19it/s]
#
#  52%|█████▏    | 25216371/48496640 [00:46<00:42, 544256.42it/s]
#
#  52%|█████▏    | 25271493/48496640 [00:46<00:42, 546303.20it/s]
#
#  52%|█████▏    | 25326199/48496640 [00:46<00:42, 546522.15it/s]
#
#  52%|█████▏    | 25380880/48496640 [00:46<00:42, 540643.36it/s]
#
#  52%|█████▏    | 25434974/48496640 [00:46<00:43, 533790.37it/s]
#
#  53%|█████▎    | 25492791/48496640 [00:46<00:42, 546850.84it/s]
#
#  53%|█████▎    | 25552521/48496640 [00:46<00:40, 561782.38it/s]
#
#  53%|█████▎    | 25608753/48496640 [00:46<00:41, 553786.32it/s]
#
#  53%|█████▎    | 25667077/48496640 [00:46<00:40, 562471.06it/s]
#  53%|█████▎    | 25725855/48496640 [00:46<00:39, 569970.46it/s]
#
#  53%|█████▎    | 25782899/48496640 [00:47<00:40, 560760.84it/s]
#
#  53%|█████▎    | 25840704/48496640 [00:47<00:40, 565852.95it/s]
#
#  53%|█████▎    | 25897815/48496640 [00:47<00:39, 567406.23it/s]
#
#  54%|█████▎    | 25954594/48496640 [00:47<00:40, 555158.07it/s]
#
#  54%|█████▎    | 26010722/48496640 [00:47<00:40, 556949.84it/s]
#
#  54%|█████▍    | 26067089/48496640 [00:47<00:40, 558930.67it/s]
#
#  54%|█████▍    | 26126160/48496640 [00:47<00:39, 568359.91it/s]
#
#  54%|█████▍    | 26183037/48496640 [00:47<00:39, 563399.59it/s]
#
#  54%|█████▍    | 26240149/48496640 [00:47<00:39, 565684.52it/s]
#
#  54%|█████▍    | 26296933/48496640 [00:47<00:39, 566322.10it/s]
#
#  54%|█████▍    | 26353585/48496640 [00:48<00:39, 561727.06it/s]
#
#  54%|█████▍    | 26409870/48496640 [00:48<00:39, 562057.24it/s]
#
#  55%|█████▍    | 26466090/48496640 [00:48<00:39, 557882.08it/s]
#
#  55%|█████▍    | 26522844/48496640 [00:48<00:39, 560746.55it/s]
#
#  55%|█████▍    | 26578932/48496640 [00:48<00:39, 558450.39it/s]
#
#  55%|█████▍    | 26635151/48496640 [00:48<00:39, 559558.45it/s]
#
#  55%|█████▌    | 26691115/48496640 [00:48<00:39, 558846.75it/s]
#
#  55%|█████▌    | 26747005/48496640 [00:48<00:39, 552305.50it/s]
#
#  55%|█████▌    | 26802708/48496640 [00:48<00:39, 553703.85it/s]
#
#  55%|█████▌    | 26858643/48496640 [00:48<00:38, 555379.73it/s]
#
#  55%|█████▌    | 26914665/48496640 [00:49<00:38, 556818.91it/s]
#
#  56%|█████▌    | 26970356/48496640 [00:49<00:39, 548114.25it/s]
#
#  56%|█████▌    | 27026507/48496640 [00:49<00:38, 552074.07it/s]
#
#  56%|█████▌    | 27085297/48496640 [00:49<00:38, 562712.74it/s]
#
#  56%|█████▌    | 27141600/48496640 [00:49<00:38, 557624.20it/s]
#
#  56%|█████▌    | 27197657/48496640 [00:49<00:38, 558492.64it/s]
#
#  56%|█████▌    | 27253528/48496640 [00:49<00:38, 557977.43it/s]
#
#  56%|█████▋    | 27310155/48496640 [00:49<00:37, 560445.39it/s]
#
#  56%|█████▋    | 27366212/48496640 [00:49<00:38, 551813.48it/s]
#
#  57%|█████▋    | 27422068/48496640 [00:49<00:38, 553802.74it/s]
#
#  57%|█████▋    | 27477476/48496640 [00:50<00:37, 553645.28it/s]
#
#  57%|█████▋    | 27532860/48496640 [00:50<00:38, 538936.70it/s]
#
#  57%|█████▋    | 27589335/48496640 [00:50<00:38, 546489.62it/s]
#
#  57%|█████▋    | 27644807/48496640 [00:50<00:37, 548911.63it/s]
#
#  57%|█████▋    | 27701241/48496640 [00:50<00:37, 553470.33it/s]
#
#  57%|█████▋    | 27756637/48496640 [00:50<00:38, 544020.61it/s]
#
#  57%|█████▋    | 27813351/48496640 [00:50<00:37, 550825.57it/s]
#
#  57%|█████▋    | 27868491/48496640 [00:50<00:37, 542872.23it/s]
#
#  58%|█████▊    | 27923194/48496640 [00:50<00:37, 544090.01it/s]
#
#  58%|█████▊    | 27980526/48496640 [00:50<00:37, 552736.56it/s]
#
#  58%|█████▊    | 28035842/48496640 [00:51<00:37, 547142.41it/s]
#
#  58%|█████▊    | 28094571/48496640 [00:51<00:36, 559015.64it/s]
#
#  58%|█████▊    | 28150516/48496640 [00:51<00:36, 558706.00it/s]
#
#  58%|█████▊    | 28206417/48496640 [00:51<00:37, 546376.14it/s]
#
#  58%|█████▊    | 28261773/48496640 [00:51<00:36, 548481.20it/s]
#
#  58%|█████▊    | 28316677/48496640 [00:51<00:36, 548640.35it/s]
#
#  59%|█████▊    | 28374799/48496640 [00:51<00:36, 558308.75it/s]
#
#  59%|█████▊    | 28430668/48496640 [00:51<00:37, 541806.46it/s]
#
#  59%|█████▊    | 28486516/48496640 [00:51<00:36, 546672.31it/s]
#
#  59%|█████▉    | 28541283/48496640 [00:52<00:36, 546545.31it/s]
#
#  59%|█████▉    | 28596007/48496640 [00:52<00:37, 533302.18it/s]
#
#  59%|█████▉    | 28653221/48496640 [00:52<00:36, 544635.15it/s]
#
#  59%|█████▉    | 28707789/48496640 [00:52<00:36, 544262.22it/s]
#
#  59%|█████▉    | 28763411/48496640 [00:52<00:36, 547793.55it/s]
#
#  59%|█████▉    | 28818287/48496640 [00:52<00:35, 548075.71it/s]
#
#  60%|█████▉    | 28873134/48496640 [00:52<00:36, 541152.70it/s]
#
#  60%|█████▉    | 28928820/48496640 [00:52<00:35, 545789.51it/s]
#
#  60%|█████▉    | 28983872/48496640 [00:52<00:35, 547191.82it/s]
#
#  60%|█████▉    | 29038619/48496640 [00:52<00:35, 542770.08it/s]
#
#  60%|█████▉    | 29094586/48496640 [00:53<00:35, 547779.97it/s]
#
#  60%|██████    | 29149387/48496640 [00:53<00:35, 545666.08it/s]
#
#  60%|██████    | 29204146/48496640 [00:53<00:35, 546233.76it/s]
#
#  60%|██████    | 29259003/48496640 [00:53<00:35, 546926.57it/s]
#
#  60%|██████    | 29313705/48496640 [00:53<00:36, 530005.97it/s]
#
#  61%|██████    | 29368166/48496640 [00:53<00:35, 534274.22it/s]
#
#  61%|██████    | 29426374/48496640 [00:53<00:34, 548360.79it/s]
#
#  61%|██████    | 29483125/48496640 [00:53<00:34, 554029.57it/s]
#
#  61%|██████    | 29540420/48496640 [00:53<00:33, 559650.68it/s]
#
#  61%|██████    | 29596439/48496640 [00:53<00:34, 547443.04it/s]
#
#  61%|██████    | 29651274/48496640 [00:54<00:34, 545633.41it/s]
#
#  61%|██████▏   | 29707021/48496640 [00:54<00:34, 549121.50it/s]
#
#  61%|██████▏   | 29761982/48496640 [00:54<00:34, 547402.07it/s]
#
#  61%|██████▏   | 29817916/48496640 [00:54<00:33, 550934.12it/s]
#
#  62%|██████▏   | 29873037/48496640 [00:54<00:33, 547875.95it/s]
#
#  62%|██████▏   | 29927846/48496640 [00:54<00:34, 542059.59it/s]
#
#  62%|██████▏   | 29983497/48496640 [00:54<00:33, 546329.33it/s]
#
#  62%|██████▏   | 30038153/48496640 [00:54<00:33, 545120.88it/s]
#
#  62%|██████▏   | 30092681/48496640 [00:54<00:33, 542175.51it/s]
#
#  62%|██████▏   | 30146911/48496640 [00:54<00:34, 539271.40it/s]
#
#  62%|██████▏   | 30204948/48496640 [00:55<00:33, 551463.20it/s]
#
#  62%|██████▏   | 30260276/48496640 [00:55<00:33, 551998.03it/s]
#
#  63%|██████▎   | 30315490/48496640 [00:55<00:33, 535925.97it/s]
#
#  63%|██████▎   | 30372719/48496640 [00:55<00:33, 546564.86it/s]
#
#  63%|██████▎   | 30427476/48496640 [00:55<00:33, 539083.18it/s]
#
#  63%|██████▎   | 30486240/48496640 [00:55<00:32, 553324.47it/s]
#
#  63%|██████▎   | 30541662/48496640 [00:55<00:32, 552637.25it/s]
#
#  63%|██████▎   | 30598897/48496640 [00:55<00:32, 558474.21it/s]
#
#  63%|██████▎   | 30654795/48496640 [00:55<00:32, 551129.15it/s]
#
#  63%|██████▎   | 30712439/48496640 [00:55<00:31, 558599.60it/s]
#
#  63%|██████▎   | 30770027/48496640 [00:56<00:31, 563723.84it/s]
#
#  64%|██████▎   | 30826439/48496640 [00:56<00:31, 553249.81it/s]
#
#  64%|██████▎   | 30881829/48496640 [00:56<00:31, 553357.50it/s]
#
#  64%|██████▍   | 30937772/48496640 [00:56<00:31, 555145.68it/s]
#
#  64%|██████▍   | 30994023/48496640 [00:56<00:31, 557329.57it/s]
#
#  64%|██████▍   | 31049782/48496640 [00:56<00:31, 553653.23it/s]
#
#  64%|██████▍   | 31105169/48496640 [00:56<00:31, 545001.22it/s]
#
#  64%|██████▍   | 31160084/48496640 [00:56<00:31, 546218.04it/s]
#
#  64%|██████▍   | 31214735/48496640 [00:56<00:32, 527894.14it/s]
#
#  64%|██████▍   | 31272410/48496640 [00:57<00:31, 542069.26it/s]
#
#  65%|██████▍   | 31326759/48496640 [00:57<00:32, 533071.51it/s]
#
#  65%|██████▍   | 31383278/48496640 [00:57<00:31, 542431.35it/s]
#
#  65%|██████▍   | 31437629/48496640 [00:57<00:32, 522240.08it/s]
#
#  65%|██████▍   | 31490059/48496640 [00:57<00:35, 483767.90it/s]
#
#  65%|██████▌   | 31539043/48496640 [00:57<00:40, 422807.74it/s]
#
#  65%|██████▌   | 31582890/48496640 [00:57<00:40, 419044.25it/s]
#
#  65%|██████▌   | 31625847/48496640 [00:57<00:46, 364596.97it/s]
#
#  65%|██████▌   | 31663996/48496640 [00:58<00:49, 343510.88it/s]
#
#  65%|██████▌   | 31699510/48496640 [00:58<00:48, 343935.35it/s]
#
#  65%|██████▌   | 31749480/48496640 [00:58<00:43, 384269.66it/s]
#
#  66%|██████▌   | 31789122/48496640 [00:58<00:44, 371807.38it/s]
#
#  66%|██████▌   | 31827152/48496640 [00:58<00:44, 374044.74it/s]
#
#  66%|██████▌   | 31880431/48496640 [00:58<00:39, 418239.09it/s]
#
#  66%|██████▌   | 31933758/48496640 [00:58<00:38, 430326.84it/s]
#
#  66%|██████▌   | 31981669/48496640 [00:58<00:37, 443950.27it/s]
#  66%|██████▌   | 32027989/48496640 [00:58<00:36, 449437.52it/s]
#
#  66%|██████▌   | 32081110/48496640 [00:58<00:34, 473104.54it/s]
#
#  66%|██████▌   | 32128738/48496640 [00:59<00:35, 463705.42it/s]
#
#  66%|██████▋   | 32181296/48496640 [00:59<00:33, 481659.97it/s]
#
#  66%|██████▋   | 32235455/48496640 [00:59<00:32, 499220.97it/s]
#
#  67%|██████▋   | 32285582/48496640 [00:59<00:36, 447035.20it/s]
#
#  67%|██████▋   | 32336361/48496640 [00:59<00:34, 463668.20it/s]
#
#  67%|██████▋   | 32383675/48496640 [00:59<00:34, 461160.91it/s]
#
#  67%|██████▋   | 32430445/48496640 [00:59<00:34, 462563.92it/s]
#
#  67%|██████▋   | 32480738/48496640 [00:59<00:33, 474209.27it/s]
#
#  67%|██████▋   | 32530547/48496640 [00:59<00:33, 481174.71it/s]
#
#  67%|██████▋   | 32578944/48496640 [01:00<00:44, 357017.35it/s]
#
#  67%|██████▋   | 32629107/48496640 [01:00<00:40, 391355.24it/s]
#
#  67%|██████▋   | 32672512/48496640 [01:00<00:46, 341551.95it/s]
#
#  67%|██████▋   | 32710553/48496640 [01:00<00:45, 343841.01it/s]
#
#  68%|██████▊   | 32761602/48496640 [01:00<00:40, 385119.45it/s]
#
#  68%|██████▊   | 32806110/48496640 [01:00<00:39, 400781.08it/s]
#
#  68%|██████▊   | 32853314/48496640 [01:00<00:37, 420149.59it/s]
#
#  68%|██████▊   | 32898139/48496640 [01:00<00:36, 426492.08it/s]
#
#  68%|██████▊   | 32942045/48496640 [01:01<00:40, 386064.73it/s]
#
#  68%|██████▊   | 32982186/48496640 [01:01<00:43, 353554.19it/s]
#
#  68%|██████▊   | 33026728/48496640 [01:01<00:41, 377181.16it/s]
#
#  68%|██████▊   | 33080143/48496640 [01:01<00:36, 419350.79it/s]
#
#  68%|██████▊   | 33135608/48496640 [01:01<00:33, 456865.09it/s]
#
#  68%|██████▊   | 33188538/48496640 [01:01<00:32, 477407.74it/s]
#
#  69%|██████▊   | 33238923/48496640 [01:01<00:31, 485031.60it/s]
#
#  69%|██████▊   | 33291849/48496640 [01:01<00:30, 496324.19it/s]
#
#  69%|██████▉   | 33348029/48496640 [01:01<00:29, 515538.25it/s]
#
#  69%|██████▉   | 33402309/48496640 [01:01<00:28, 523590.59it/s]
#
#  69%|██████▉   | 33454983/48496640 [01:02<00:28, 522204.83it/s]
#
#  69%|██████▉   | 33509902/48496640 [01:02<00:28, 530210.89it/s]
#
#  69%|██████▉   | 33563086/48496640 [01:02<00:28, 527331.99it/s]
#
#  69%|██████▉   | 33617850/48496640 [01:02<00:27, 533359.77it/s]
#
#  69%|██████▉   | 33672962/48496640 [01:02<00:27, 538648.07it/s]
#
#  70%|██████▉   | 33726892/48496640 [01:02<00:27, 530758.23it/s]
#
#  70%|██████▉   | 33781178/48496640 [01:02<00:27, 534334.06it/s]
#
#  70%|██████▉   | 33834665/48496640 [01:02<00:27, 530078.20it/s]
#
#  70%|██████▉   | 33888595/48496640 [01:02<00:27, 532805.08it/s]
#
#  70%|██████▉   | 33941908/48496640 [01:02<00:27, 528122.74it/s]
#
#  70%|███████   | 33996085/48496640 [01:03<00:27, 532162.51it/s]
#
#  70%|███████   | 34050942/48496640 [01:03<00:26, 537036.71it/s]
#
#  70%|███████   | 34104668/48496640 [01:03<00:27, 529865.73it/s]
#
#  70%|███████   | 34158892/48496640 [01:03<00:26, 533522.13it/s]
#
#  71%|███████   | 34212273/48496640 [01:03<00:26, 529420.16it/s]
#
#  71%|███████   | 34268783/48496640 [01:03<00:26, 539988.16it/s]
#
#  71%|███████   | 34325277/48496640 [01:03<00:25, 547403.38it/s]
#
#  71%|███████   | 34380045/48496640 [01:03<00:26, 540868.58it/s]
#
#  71%|███████   | 34434977/48496640 [01:03<00:25, 543367.67it/s]
#
#  71%|███████   | 34489341/48496640 [01:04<00:26, 535884.92it/s]
#
#  71%|███████   | 34543464/48496640 [01:04<00:25, 537457.22it/s]
#
#  71%|███████▏  | 34597491/48496640 [01:04<00:25, 538275.70it/s]
#
#  71%|███████▏  | 34652978/48496640 [01:04<00:25, 543209.58it/s]
#
#  72%|███████▏  | 34709356/48496640 [01:04<00:25, 549340.96it/s]
#
#  72%|███████▏  | 34764307/48496640 [01:04<00:25, 539919.59it/s]
#
#  72%|███████▏  | 34818630/48496640 [01:04<00:25, 540893.53it/s]
#
#  72%|███████▏  | 34872752/48496640 [01:04<00:25, 535990.60it/s]
#
#  72%|███████▏  | 34927847/48496640 [01:04<00:25, 540412.45it/s]
#
#  72%|███████▏  | 34981915/48496640 [01:04<00:25, 533954.02it/s]
#
#  72%|███████▏  | 35039046/48496640 [01:05<00:24, 544984.75it/s]
#
#  72%|███████▏  | 35094488/48496640 [01:05<00:24, 547780.01it/s]
#
#  72%|███████▏  | 35149296/48496640 [01:05<00:24, 546152.03it/s]
#
#  73%|███████▎  | 35203932/48496640 [01:05<00:24, 545582.80it/s]
#
#  73%|███████▎  | 35258505/48496640 [01:05<00:24, 536093.14it/s]
#
#  73%|███████▎  | 35312902/48496640 [01:05<00:24, 538411.64it/s]
#
#  73%|███████▎  | 35366777/48496640 [01:05<00:25, 519959.25it/s]
#
#  73%|███████▎  | 35418916/48496640 [01:05<00:28, 466703.63it/s]
#
#  73%|███████▎  | 35474148/48496640 [01:05<00:26, 489910.19it/s]
#
#  73%|███████▎  | 35527205/48496640 [01:05<00:25, 501243.49it/s]
#
#  73%|███████▎  | 35581906/48496640 [01:06<00:25, 514287.15it/s]
#
#  73%|███████▎  | 35633937/48496640 [01:06<00:25, 513509.35it/s]
#
#  74%|███████▎  | 35685708/48496640 [01:06<00:24, 513496.70it/s]
#
#  74%|███████▎  | 35737676/48496640 [01:06<00:24, 515305.84it/s]
#
#  74%|███████▍  | 35793446/48496640 [01:06<00:24, 527812.71it/s]
#
#  74%|███████▍  | 35848645/48496640 [01:06<00:23, 534979.20it/s]
#
#  74%|███████▍  | 35902267/48496640 [01:06<00:24, 518335.88it/s]
#
#  74%|███████▍  | 35954292/48496640 [01:06<00:26, 479255.15it/s]
#
#  74%|███████▍  | 36008366/48496640 [01:06<00:25, 496337.82it/s]
#
#  74%|███████▍  | 36065988/48496640 [01:07<00:23, 519033.98it/s]
#
#  74%|███████▍  | 36124046/48496640 [01:07<00:23, 536799.58it/s]
#
#  75%|███████▍  | 36178174/48496640 [01:07<00:23, 533363.30it/s]
#
#  75%|███████▍  | 36231854/48496640 [01:07<00:22, 534363.23it/s]
#
#  75%|███████▍  | 36288521/48496640 [01:07<00:22, 543881.21it/s]
#
#  75%|███████▍  | 36343081/48496640 [01:07<00:22, 541452.69it/s]
#
#  75%|███████▌  | 36399892/48496640 [01:07<00:22, 549342.40it/s]
#
#  75%|███████▌  | 36454921/48496640 [01:07<00:25, 473446.61it/s]
#
#  75%|███████▌  | 36512482/48496640 [01:07<00:23, 500812.23it/s]
#
#  75%|███████▌  | 36568953/48496640 [01:07<00:23, 518494.27it/s]
#
#  76%|███████▌  | 36624927/48496640 [01:08<00:22, 530176.17it/s]
#
#  76%|███████▌  | 36679722/48496640 [01:08<00:22, 535291.68it/s]
#
#  76%|███████▌  | 36733959/48496640 [01:08<00:22, 524316.74it/s]
#
#  76%|███████▌  | 36789983/48496640 [01:08<00:21, 534694.33it/s]
#
#  76%|███████▌  | 36844569/48496640 [01:08<00:21, 537952.00it/s]
#
#  76%|███████▌  | 36901562/48496640 [01:08<00:21, 547364.06it/s]
#
#  76%|███████▌  | 36956522/48496640 [01:08<00:22, 521417.13it/s]
#
#  76%|███████▋  | 37009059/48496640 [01:08<00:23, 479258.38it/s]
#
#  76%|███████▋  | 37060447/48496640 [01:08<00:23, 488712.69it/s]
#
#  77%|███████▋  | 37115387/48496640 [01:09<00:22, 505746.15it/s]
#
#  77%|███████▋  | 37174095/48496640 [01:09<00:21, 529026.62it/s]
#
#  77%|███████▋  | 37227524/48496640 [01:09<00:21, 518368.33it/s]
#
#  77%|███████▋  | 37285409/48496640 [01:09<00:20, 535798.83it/s]
#
#  77%|███████▋  | 37339334/48496640 [01:09<00:20, 531986.02it/s]
#
#  77%|███████▋  | 37397082/48496640 [01:09<00:20, 545278.28it/s]
#
#  77%|███████▋  | 37451812/48496640 [01:09<00:20, 540108.45it/s]
#
#  77%|███████▋  | 37505968/48496640 [01:09<00:23, 468036.51it/s]
#
#  77%|███████▋  | 37561603/48496640 [01:09<00:22, 491580.85it/s]
#
#  78%|███████▊  | 37616451/48496640 [01:10<00:21, 507272.49it/s]
#
#  78%|███████▊  | 37675464/48496640 [01:10<00:20, 530689.59it/s]
#
#  78%|███████▊  | 37731158/48496640 [01:10<00:20, 538234.26it/s]
#
#  78%|███████▊  | 37785702/48496640 [01:10<00:19, 539318.94it/s]
#
#  78%|███████▊  | 37840983/48496640 [01:10<00:19, 543267.91it/s]
#
#  78%|███████▊  | 37898018/48496640 [01:10<00:19, 551261.82it/s]
#
#  78%|███████▊  | 37953412/48496640 [01:10<00:19, 542344.47it/s]
#
#  78%|███████▊  | 38007860/48496640 [01:10<00:20, 519481.35it/s]
#
#  78%|███████▊  | 38063067/48496640 [01:10<00:19, 528811.65it/s]
#
#  79%|███████▊  | 38120469/48496640 [01:10<00:19, 541940.09it/s]
#  79%|███████▊  | 38178705/48496640 [01:11<00:18, 553792.09it/s]
#
#  79%|███████▉  | 38234273/48496640 [01:11<00:18, 544943.58it/s]
#
#  79%|███████▉  | 38290625/48496640 [01:11<00:18, 550382.73it/s]
#
#  79%|███████▉  | 38345805/48496640 [01:11<00:18, 545295.20it/s]
#
#  79%|███████▉  | 38403520/48496640 [01:11<00:18, 554668.70it/s]
#
#  79%|███████▉  | 38460235/48496640 [01:11<00:17, 558357.77it/s]
#
#  79%|███████▉  | 38516131/48496640 [01:11<00:18, 546995.17it/s]
#
#  80%|███████▉  | 38572028/48496640 [01:11<00:18, 550507.36it/s]
#
#  80%|███████▉  | 38627383/48496640 [01:11<00:17, 551401.05it/s]
#
#  80%|███████▉  | 38682572/48496640 [01:11<00:18, 543800.82it/s]
#
#  80%|███████▉  | 38739866/48496640 [01:12<00:17, 552388.97it/s]
#
#  80%|███████▉  | 38795156/48496640 [01:12<00:17, 547124.38it/s]
#
#  80%|████████  | 38849910/48496640 [01:12<00:17, 538580.07it/s]
#
#  80%|████████  | 38904709/48496640 [01:12<00:17, 541335.89it/s]
#
#  80%|████████  | 38959962/48496640 [01:12<00:17, 544638.37it/s]
#
#  80%|████████  | 39014459/48496640 [01:12<00:17, 541704.57it/s]
#
#  81%|████████  | 39068653/48496640 [01:12<00:19, 485571.77it/s]
#
#  81%|████████  | 39123702/48496640 [01:12<00:18, 503432.38it/s]
#
#  81%|████████  | 39178471/48496640 [01:12<00:18, 515909.50it/s]
#
#  81%|████████  | 39234889/48496640 [01:12<00:17, 529774.92it/s]
#
#  81%|████████  | 39289779/48496640 [01:13<00:17, 535327.11it/s]
#
#  81%|████████  | 39344356/48496640 [01:13<00:16, 538387.29it/s]
#
#  81%|████████  | 39401316/48496640 [01:13<00:16, 547608.59it/s]
#
#  81%|████████▏ | 39456297/48496640 [01:13<00:16, 541442.06it/s]
#
#  81%|████████▏ | 39513042/48496640 [01:13<00:16, 549112.14it/s]
#
#  82%|████████▏ | 39568082/48496640 [01:13<00:16, 539007.34it/s]
#
#  82%|████████▏ | 39622964/48496640 [01:13<00:16, 541882.44it/s]
#
#  82%|████████▏ | 39678142/48496640 [01:13<00:16, 544792.64it/s]
#
#  82%|████████▏ | 39732691/48496640 [01:13<00:16, 538687.55it/s]
#
#  82%|████████▏ | 39787728/48496640 [01:14<00:16, 542132.26it/s]
#
#  82%|████████▏ | 39841988/48496640 [01:14<00:16, 533779.04it/s]
#
#  82%|████████▏ | 39898405/48496640 [01:14<00:15, 542722.69it/s]
#
#  82%|████████▏ | 39956224/48496640 [01:14<00:15, 553217.10it/s]
#
#  83%|████████▎ | 40011598/48496640 [01:14<00:15, 547224.63it/s]
#
#  83%|████████▎ | 40069398/48496640 [01:14<00:15, 556308.53it/s]
#
#  83%|████████▎ | 40125088/48496640 [01:14<00:15, 556479.62it/s]
#
#  83%|████████▎ | 40180768/48496640 [01:14<00:15, 548372.05it/s]
#
#  83%|████████▎ | 40235781/48496640 [01:14<00:15, 548876.45it/s]
#
#  83%|████████▎ | 40290701/48496640 [01:14<00:15, 542371.23it/s]
#
#  83%|████████▎ | 40346555/48496640 [01:15<00:14, 547139.54it/s]
#
#  83%|████████▎ | 40401300/48496640 [01:15<00:14, 546494.75it/s]
#
#  83%|████████▎ | 40455971/48496640 [01:15<00:14, 540982.48it/s]
#
#  84%|████████▎ | 40512948/48496640 [01:15<00:14, 549499.44it/s]
#
#  84%|████████▎ | 40567926/48496640 [01:15<00:14, 543789.97it/s]
#
#  84%|████████▍ | 40623224/48496640 [01:15<00:14, 546505.19it/s]
#
#  84%|████████▍ | 40678829/48496640 [01:15<00:14, 549336.79it/s]
#
#  84%|████████▍ | 40733782/48496640 [01:15<00:14, 543421.85it/s]
#
#  84%|████████▍ | 40789865/48496640 [01:15<00:14, 548573.23it/s]
#
#  84%|████████▍ | 40845397/48496640 [01:15<00:13, 550576.57it/s]
#
#  84%|████████▍ | 40900473/48496640 [01:16<00:13, 545684.86it/s]
#
#  84%|████████▍ | 40958704/48496640 [01:16<00:13, 556552.53it/s]
#
#  85%|████████▍ | 41014385/48496640 [01:16<00:13, 548563.26it/s]
#
#  85%|████████▍ | 41070455/48496640 [01:16<00:13, 552143.76it/s]
#
#  85%|████████▍ | 41126604/48496640 [01:16<00:13, 554913.91it/s]
#
#  85%|████████▍ | 41182122/48496640 [01:16<00:13, 550410.49it/s]
#
#  85%|████████▌ | 41237850/48496640 [01:16<00:13, 552443.52it/s]
#
#  85%|████████▌ | 41293113/48496640 [01:16<00:13, 543931.66it/s]
#
#  85%|████████▌ | 41347695/48496640 [01:16<00:13, 544482.92it/s]
#
#  85%|████████▌ | 41404527/48496640 [01:16<00:12, 551546.04it/s]
#
#  85%|████████▌ | 41459709/48496640 [01:17<00:12, 547841.63it/s]
#
#  86%|████████▌ | 41515441/48496640 [01:17<00:12, 550652.39it/s]
#
#  86%|████████▌ | 41570525/48496640 [01:17<00:12, 543630.06it/s]
#
#  86%|████████▌ | 41624917/48496640 [01:17<00:12, 542325.16it/s]
#
#  86%|████████▌ | 41682100/48496640 [01:17<00:12, 551068.94it/s]
#
#  86%|████████▌ | 41737231/48496640 [01:17<00:12, 548055.96it/s]
#
#  86%|████████▌ | 41792055/48496640 [01:17<00:12, 537807.57it/s]
#
#  86%|████████▋ | 41846897/48496640 [01:17<00:12, 540922.87it/s]
#
#  86%|████████▋ | 41904431/48496640 [01:17<00:11, 551096.91it/s]
#
#  87%|████████▋ | 41959583/48496640 [01:17<00:12, 537451.63it/s]
#
#  87%|████████▋ | 42014970/48496640 [01:18<00:11, 542249.03it/s]
#
#  87%|████████▋ | 42069272/48496640 [01:18<00:12, 531437.20it/s]
#
#  87%|████████▋ | 42123071/48496640 [01:18<00:11, 533346.10it/s]
#
#  87%|████████▋ | 42180201/48496640 [01:18<00:11, 544517.98it/s]
#
#  87%|████████▋ | 42234720/48496640 [01:18<00:11, 537813.56it/s]
#
#  87%|████████▋ | 42289567/48496640 [01:18<00:11, 540947.16it/s]
#
#  87%|████████▋ | 42345213/48496640 [01:18<00:11, 545007.35it/s]
#
#  87%|████████▋ | 42400730/48496640 [01:18<00:11, 548022.29it/s]
#
#  88%|████████▊ | 42457893/48496640 [01:18<00:10, 555045.81it/s]
#
#  88%|████████▊ | 42513423/48496640 [01:18<00:10, 551279.59it/s]
#
#  88%|████████▊ | 42569230/48496640 [01:19<00:10, 553294.71it/s]
#
#  88%|████████▊ | 42624577/48496640 [01:19<00:10, 540837.96it/s]
#
#  88%|████████▊ | 42678729/48496640 [01:19<00:10, 540875.23it/s]
#
#  88%|████████▊ | 42733204/48496640 [01:19<00:10, 542018.58it/s]
#
#  88%|████████▊ | 42787441/48496640 [01:19<00:10, 541841.49it/s]
#
#  88%|████████▊ | 42841650/48496640 [01:19<00:10, 524121.74it/s]
#
#  88%|████████▊ | 42896701/48496640 [01:19<00:10, 531804.12it/s]
#
#  89%|████████▊ | 42954110/48496640 [01:19<00:10, 544222.03it/s]
#
#  89%|████████▊ | 43008638/48496640 [01:19<00:10, 542723.74it/s]
#
#  89%|████████▉ | 43062984/48496640 [01:20<00:10, 538435.02it/s]
#
#  89%|████████▉ | 43117323/48496640 [01:20<00:09, 539896.46it/s]
#
#  89%|████████▉ | 43171353/48496640 [01:20<00:09, 538990.67it/s]
#
#  89%|████████▉ | 43225280/48496640 [01:20<00:09, 535171.32it/s]
#
#  89%|████████▉ | 43279644/48496640 [01:20<00:09, 537678.48it/s]
#
#  89%|████████▉ | 43333431/48496640 [01:20<00:09, 534796.30it/s]
#
#  89%|████████▉ | 43387770/48496640 [01:20<00:09, 537343.90it/s]
#
#  90%|████████▉ | 43442868/48496640 [01:20<00:09, 541399.48it/s]
#
#  90%|████████▉ | 43497020/48496640 [01:20<00:09, 524717.65it/s]
#
#  90%|████████▉ | 43553409/48496640 [01:20<00:09, 536171.89it/s]
#
#  90%|████████▉ | 43608818/48496640 [01:21<00:09, 541438.69it/s]
#
#  90%|█████████ | 43663601/48496640 [01:21<00:08, 543317.84it/s]
#
#  90%|█████████ | 43718803/48496640 [01:21<00:08, 545892.66it/s]
#
#  90%|█████████ | 43773450/48496640 [01:21<00:08, 546056.03it/s]
#
#  90%|█████████ | 43828759/48496640 [01:21<00:08, 548152.17it/s]
#
#  90%|█████████ | 43883598/48496640 [01:21<00:08, 547850.38it/s]
#
#  91%|█████████ | 43938400/48496640 [01:21<00:08, 545561.81it/s]
#
#  91%|█████████ | 43994047/48496640 [01:21<00:08, 548813.59it/s]
#
#  91%|█████████ | 44048940/48496640 [01:21<00:08, 545670.24it/s]
#
#  91%|█████████ | 44103518/48496640 [01:21<00:08, 545378.32it/s]
#
#  91%|█████████ | 44158090/48496640 [01:22<00:07, 545475.43it/s]
#
#  91%|█████████ | 44212643/48496640 [01:22<00:07, 542971.61it/s]
#
#  91%|█████████▏| 44266946/48496640 [01:22<00:08, 516967.86it/s]
#
#  91%|█████████▏| 44321805/48496640 [01:22<00:07, 526090.56it/s]
#
#  92%|█████████▏| 44376299/48496640 [01:22<00:07, 531588.49it/s]
#
#  92%|█████████▏| 44429937/48496640 [01:22<00:07, 532994.36it/s]
#
#  92%|█████████▏| 44485914/48496640 [01:22<00:07, 540916.13it/s]
#  92%|█████████▏| 44543267/48496640 [01:22<00:07, 550591.81it/s]
#
#  92%|█████████▏| 44598515/48496640 [01:22<00:07, 551150.76it/s]
#
#  92%|█████████▏| 44653683/48496640 [01:22<00:06, 549306.28it/s]
#
#  92%|█████████▏| 44708652/48496640 [01:23<00:06, 543311.46it/s]
#
#  92%|█████████▏| 44764174/48496640 [01:23<00:06, 546837.18it/s]
#
#  92%|█████████▏| 44818889/48496640 [01:23<00:06, 546505.17it/s]
#
#  93%|█████████▎| 44873738/48496640 [01:23<00:06, 547082.97it/s]
#
#  93%|█████████▎| 44928745/48496640 [01:23<00:06, 547970.13it/s]
#
#  93%|█████████▎| 44986287/48496640 [01:23<00:06, 556160.98it/s]
#
#  93%|█████████▎| 45041914/48496640 [01:23<00:06, 544544.96it/s]
#
#  93%|█████████▎| 45096615/48496640 [01:23<00:06, 545269.11it/s]
#
#  93%|█████████▎| 45154081/48496640 [01:23<00:06, 553979.87it/s]
#
#  93%|█████████▎| 45209519/48496640 [01:23<00:06, 543323.38it/s]
#
#  93%|█████████▎| 45263918/48496640 [01:24<00:05, 543504.79it/s]
#
#  93%|█████████▎| 45319499/48496640 [01:24<00:05, 547143.17it/s]
#
#  94%|█████████▎| 45374252/48496640 [01:24<00:05, 539372.55it/s]
#
#  94%|█████████▎| 45428235/48496640 [01:24<00:05, 539153.50it/s]
#
#  94%|█████████▍| 45483370/48496640 [01:24<00:05, 542763.83it/s]
#
#  94%|█████████▍| 45537673/48496640 [01:24<00:05, 538189.30it/s]
#
#  94%|█████████▍| 45594618/48496640 [01:24<00:05, 547449.19it/s]
#
#  94%|█████████▍| 45649391/48496640 [01:24<00:05, 543061.07it/s]
#
#  94%|█████████▍| 45706368/48496640 [01:24<00:05, 550974.25it/s]
#
#  94%|█████████▍| 45761546/48496640 [01:24<00:04, 551211.02it/s]
#
#  94%|█████████▍| 45816686/48496640 [01:25<00:04, 543911.83it/s]
#
#  95%|█████████▍| 45871160/48496640 [01:25<00:04, 544151.73it/s]
#
#  95%|█████████▍| 45925598/48496640 [01:25<00:04, 539843.66it/s]
#
#  95%|█████████▍| 45979602/48496640 [01:25<00:04, 535140.45it/s]
#
#  95%|█████████▍| 46033381/48496640 [01:25<00:04, 535918.45it/s]
#
#  95%|█████████▌| 46088179/48496640 [01:25<00:04, 539496.07it/s]
#
#  95%|█████████▌| 46142142/48496640 [01:25<00:04, 537848.90it/s]
#
#  95%|█████████▌| 46197239/48496640 [01:25<00:04, 541753.57it/s]
#
#  95%|█████████▌| 46252090/48496640 [01:25<00:04, 543764.46it/s]
#
#  95%|█████████▌| 46306475/48496640 [01:26<00:04, 535143.40it/s]
#
#  96%|█████████▌| 46361533/48496640 [01:26<00:03, 539698.56it/s]
#
#  96%|█████████▌| 46415533/48496640 [01:26<00:03, 537553.09it/s]
#
#  96%|█████████▌| 46469310/48496640 [01:26<00:03, 531205.52it/s]
#
#  96%|█████████▌| 46526280/48496640 [01:26<00:03, 542573.22it/s]
#
#  96%|█████████▌| 46580573/48496640 [01:26<00:03, 538493.32it/s]
#
#  96%|█████████▌| 46635629/48496640 [01:26<00:03, 542063.47it/s]
#
#  96%|█████████▋| 46690377/48496640 [01:26<00:03, 543669.26it/s]
#
#  96%|█████████▋| 46744763/48496640 [01:26<00:03, 537616.27it/s]
#
#  97%|█████████▋| 46799666/48496640 [01:26<00:03, 540992.60it/s]
#
#  97%|█████████▋| 46854246/48496640 [01:27<00:03, 542419.01it/s]
#
#  97%|█████████▋| 46908505/48496640 [01:27<00:02, 537943.77it/s]
#
#  97%|█████████▋| 46963170/48496640 [01:27<00:02, 540523.26it/s]
#
#  97%|█████████▋| 47018457/48496640 [01:27<00:02, 544198.02it/s]
#
#  97%|█████████▋| 47072890/48496640 [01:27<00:02, 542879.51it/s]
#
#  97%|█████████▋| 47130240/48496640 [01:27<00:02, 552010.20it/s]
#
#  97%|█████████▋| 47186934/48496640 [01:27<00:02, 556466.85it/s]
#
#  97%|█████████▋| 47242591/48496640 [01:27<00:02, 550565.39it/s]
#
#  98%|█████████▊| 47300069/48496640 [01:27<00:02, 557749.39it/s]
#
#  98%|█████████▊| 47355865/48496640 [01:27<00:02, 548596.17it/s]
#
#  98%|█████████▊| 47414057/48496640 [01:28<00:01, 558426.63it/s]
#
#  98%|█████████▊| 47469946/48496640 [01:28<00:01, 554747.06it/s]
#
#  98%|█████████▊| 47525455/48496640 [01:28<00:01, 548279.19it/s]
#
#  98%|█████████▊| 47580863/48496640 [01:28<00:01, 549983.39it/s]
#
#  98%|█████████▊| 47636725/48496640 [01:28<00:01, 552537.99it/s]
#
#  98%|█████████▊| 47692001/48496640 [01:28<00:01, 545041.23it/s]
#
#  98%|█████████▊| 47747827/48496640 [01:28<00:01, 548933.26it/s]
#
#  99%|█████████▊| 47803280/48496640 [01:28<00:01, 550581.16it/s]
#
#  99%|█████████▊| 47858361/48496640 [01:28<00:01, 529653.94it/s]
#
#  99%|█████████▉| 47914879/48496640 [01:28<00:01, 539962.85it/s]
#
#  99%|█████████▉| 47970532/48496640 [01:29<00:00, 544815.73it/s]
#
#  99%|█████████▉| 48025134/48496640 [01:29<00:00, 533019.20it/s]
#
#  99%|█████████▉| 48081987/48496640 [01:29<00:00, 543382.18it/s]
#
#  99%|█████████▉| 48136442/48496640 [01:29<00:00, 542363.26it/s]
#
#  99%|█████████▉| 48190759/48496640 [01:29<00:00, 536630.55it/s]
#
#  99%|█████████▉| 48245032/48496640 [01:29<00:00, 538422.10it/s]
#
# 100%|█████████▉| 48300140/48496640 [01:29<00:00, 539842.61it/s]
#
# 100%|█████████▉| 48354322/48496640 [01:29<00:00, 540426.15it/s]
#
# 100%|█████████▉| 48408768/48496640 [01:29<00:00, 541621.59it/s]
#
# 100%|██████████| 48496640/48496640 [01:30<00:00, 538626.45it/s]

# %%
vertices_colors = np.array(vertices_colors)
vertices_colors.shape
# Out:
# (48496640, 3)

# %%
vertices.shape
# Out:
# (48496640, 3)

# %%
from utilis.utilis import writePlyFile

file_dir = "/data/cornucopia/jz522/experiments/model_visualisation/reg_clas_model__17_05_2021/"
file_name = "MSE_point_cloud_sampled_100.ply"

writePlyFile(file_dir, file_name, vertices, vertices_colors, sample=100)

# %% [markdown]
# ## inspect

# %%
# inspect where the model makes errors
#   Q: what object categories does the model poorly predict on?
#   Q: what parts of the building does it poorly predict on?
#   Q: which cameras does the model predict worse on?
#   Q: how does positioning of validation cameras affects error?
#   Q:
